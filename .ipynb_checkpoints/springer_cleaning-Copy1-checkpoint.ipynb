# %%
import SpringerFetch
import json
import helper
import re
import pandas as pd
import helper
import importlib
import requests
import SpringerParse
importlib.reload(helper)
importlib.reload(SpringerFetch)
importlib.reload(SpringerParse)
# Out:
# <module 'SpringerParse' from '/Users/sophierand/Desktop/Github/lit_rev_tool/SpringerParse.py'>

# %%
api_key = 'f769b196821d177a5ca1d3252cb0bb2f'
input_term = "syndromic+surveillance"
record_count = 10

# %%
springer_fetch_inst = SpringerFetch.springer_fetch(input_term,api_key)

# %%
url = springer_fetch_inst.ping_api()
url
# Out:
# 'http://api.springer.com/metadata/json?q=(type:Journal AND keyword:"syndromic+surveillance")&p=100&api_key=f769b196821d177a5ca1d3252cb0bb2f'

# %%
results,record_count = springer_fetch_inst.pull_results(url)

# %%
prop_dict = springer_fetch_inst.search_properties(record_count)
prop_dict
# Out:
# {'id': 'NBr2c8hhGiorpIJbEmCfG9rVC',
#  'id_type': 'fetch',
#  'input_db': 'springer',
#  'record_count': 47,
#  'run_date': '2018-04-25 14:39'}

# %%
unique_id = prop_dict['id']
helper.serialize_output(unique_id,results['records'])
helper.update_id_json(prop_dict)

# %%
new_results = helper.id_run('fetch')

# %%
parse_df = helper.id_run('parse','springer')

# %%
parse_df
# Out:
#                                              abstract  \
# 0   AbstractBackgroundRefugees may have an increas...
# 1   AbstractBackgroundWildlife rehabilitation cent...
# 2   AbstractBackgroundAs service provision and pat...
# 3   AbstractBackgroundIn the winter and spring of ...
# 4   AbstractBackgroundIn an era of ubiquitous elec...
# 5   AbstractBackgroundSyndromic surveillance has b...
# 6   AbstractDesigning effective mitigation strateg...
# 7   AbstractBackgroundTick paralysis, resultant fr...
# 8   AbstractSurveillance of epidemic outbreaks and...
# 9   AbstractBackgroundThe emergency department (ED...
# 10  AbstractBackgroundSyndromic surveillance is a ...
# 11  AbstractAchieving effective wildlife disease s...
# 12  AbstractBackgroundSyndromic surveillance syste...
# 13  AbstractBackgroundStudies into the costs of sy...
# 14  AbstractBackgroundDeath certificates provide a...
# 15  AbstractA systemic model for making sense of h...
# 16  AbstractBackgroundEarly warning and robust est...
# 17  AbstractPurposeThe purpose of this study was t...
# 18  RésuméAu Sénégal, la surveillance de la grippe...
# 19  AbstractBackgroundFor researchers and public h...
# 20  AbstractBackgroundThis systematic literature r...
# 21  AbstractThe scope of the International Health ...
# 22  AbstractBackgroundEarly knowledge of influenza...
# 23  AbstractBackgroundWe evaluated Swiss slaughter...
# 24  AbstractBackgroundAbattoir condemnation data s...
# 25  AbstractBackgroundA study of the impacts on re...
# 26  AbstractBackgroundEmergency medical service (E...
# 27  AbstractBackgroundThe objective of this study ...
# 28  AbstractBackgroundThe slaughterhouse is a cent...
# 29  AbstractBackgroundLittle is known about the po...
# 30  AbstractBackgroundAlthough an increasing numbe...
# 31  AbstractBackgroundAnimal disease monitoring an...
# 32  AbstractBackgroundA crucial goal of infectious...
# 33  AbstractBackgroundFrom January 30-February 6, ...
# 34
# 35  AbstractBackgroundWe conducted a pilot utility...
# 36  AbstractBackgroundThe importance of wildlife d...
# 37  AbstractTo better describe the epidemiology of...
# 38  ZusammenfassungZur zeitnahen Gewinnung belastb...
# 39  AbstractBackgroundOntario provincial abattoirs...
# 40  AbstractDisease surveillance makes use of info...
# 41  AbstractBackgroundThe Department of Defense Mi...
# 42  AbstractSyndromic surveillance uses new ways o...
# 43  AbstractIn 1998, the New York City Department ...
# 44  AbstractThis article presents an, algorithm fo...
# 45  AbstractSyndromic surveillance systems can det...
# 46  AbstractInterest in public health surveillance...
#
#                       associatedId  \
# 0    doi:10.1186/s12916-018-1015-9
# 1    doi:10.1186/s12917-017-1292-0
# 2    doi:10.1186/s12889-017-4372-y
# 3    doi:10.1186/s12889-017-4233-8
# 4    doi:10.1186/s12917-016-0914-2
# 5    doi:10.1186/s13104-016-2098-z
# 6    doi:10.1007/s10696-014-9204-0
# 7    doi:10.1186/s13071-016-1590-6
# 8    doi:10.1007/s10618-015-0434-x
# 9    doi:10.1186/s12873-016-0080-7
# 10   doi:10.1186/s12889-015-2680-7
# 11   doi:10.1007/s10393-015-1054-z
# 12   doi:10.1186/s12889-015-2475-x
# 13   doi:10.1186/s12913-015-0965-2
# 14   doi:10.1186/s12911-015-0174-2
# 15   doi:10.1007/s13218-015-0349-0
# 16   doi:10.1186/s12879-015-0789-z
# 17   doi:10.1007/s11250-014-0736-9
# 18   doi:10.1007/s13149-014-0390-5
# 19   doi:10.1186/s12911-014-0108-4
# 20   doi:10.1186/s12879-014-0604-2
# 21        doi:10.1057/jphp.2014.13
# 22    doi:10.1186/1471-2334-14-381
# 23     doi:10.1186/1746-6148-10-33
# 24     doi:10.1186/1746-6148-9-231
# 25     doi:10.1186/1476-069X-12-94
# 26    doi:10.1186/1471-2458-13-905
# 27    doi:10.1186/1472-6947-13-101
# 28      doi:10.1186/1746-6148-9-88
# 29     doi:10.1186/1472-6947-13-40
# 30    doi:10.1186/1471-2458-12-929
# 31     doi:10.1186/1746-6148-8-192
# 32      doi:10.1186/1472-6947-12-4
# 33      doi:10.1186/1476-069X-11-3
# 34  doi:10.1186/1753-6561-5-S6-P33
# 35     doi:10.1186/1756-0500-4-187
# 36      doi:10.1186/1746-6148-6-56
# 37     doi:10.1186/1743-422X-7-321
# 38   doi:10.1007/s00103-010-1117-9
# 39      doi:10.1186/1746-6148-6-42
# 40      doi:10.1186/1476-072X-9-16
# 41       doi:10.1186/1476-072X-9-1
# 42   doi:10.1007/s11673-009-9163-4
# 43          doi:10.1007/PL00022314
# 44          doi:10.1007/PL00022317
# 45          doi:10.1007/PL00022321
# 46          doi:10.1007/PL00022309
#
#                                                author journalISO  \
# 0   [{'first_name': ' Amanda M.', 'last_name': 'Ro...      12916
# 1   [{'first_name': ' Alba', 'last_name': 'Ana', '...      12917
# 2   [{'first_name': ' Elizabeth', 'last_name': 'Bu...      12889
# 3   [{'first_name': ' Pär', 'last_name': 'Bjelkmar...      12889
# 4   [{'first_name': ' Flavie', 'last_name': 'Vial'...      12917
# 5   [{'first_name': ' Chuchu', 'last_name': 'Ye', ...      13104
# 6   [{'first_name': ' Taesik', 'last_name': 'Lee',...      10696
# 7   [{'first_name': ' Vanina', 'last_name': 'Guern...      13071
# 8   [{'first_name': ' Liangzhe', 'last_name': 'Che...      10618
# 9   [{'first_name': ' Samantha F.', 'last_name': '...      12873
# 10  [{'first_name': ' Ruth A.', 'last_name': 'Asht...      12889
# 11  [{'first_name': ' Becki', 'last_name': 'Lawson...      10393
# 12  [{'first_name': ' Yan', 'last_name': 'Ding', '...      12889
# 13  [{'first_name': ' Yan', 'last_name': 'Ding', '...      12913
# 14  [{'first_name': ' Bevan', 'last_name': 'Koopma...      12911
# 15  [{'first_name': ' Magnus', 'last_name': 'Boman...      13218
# 16  [{'first_name': ' Lydia N', 'last_name': 'Drum...      12879
# 17  [{'first_name': ' Abu James', 'last_name': 'Su...      11250
# 18  [{'first_name': ' D.', 'last_name': 'Thiam', '...      13149
# 19  [{'first_name': ' Jian', 'last_name': 'Zou', '...      12911
# 20  [{'first_name': ' Mathilde', 'last_name': 'Piv...      12879
# 21  [{'first_name': ' Nicole', 'last_name': 'Rosen...      41271
# 22  [{'first_name': ' Solweig', 'last_name': 'Gerb...      12879
# 23  [{'first_name': ' Flavie', 'last_name': 'Vial'...      12917
# 24  [{'first_name': ' Gillian D', 'last_name': 'Al...      12917
# 25  [{'first_name': ' Brian', 'last_name': 'Thelen...      12940
# 26  [{'first_name': ' Nicole', 'last_name': 'Rosen...      12889
# 27  [{'first_name': ' Solweig', 'last_name': 'Gerb...      12911
# 28  [{'first_name': ' Céline', 'last_name': 'Dupuy...      12917
# 29  [{'first_name': ' Aaron W', 'last_name': 'Cash...      12911
# 30  [{'first_name': ' Anna', 'last_name': 'Chu', '...      12889
# 31  [{'first_name': ' Terri L', 'last_name': 'O’Su...      12917
# 32  [{'first_name': ' Wei-rong', 'last_name': 'Yan...      12911
# 33  [{'first_name': ' Andrea', 'last_name': 'Schaf...      12940
# 34  [{'first_name': ' C', 'last_name': 'King', 'co...      12919
# 35  [{'first_name': ' Blaine', 'last_name': 'Reede...      13104
# 36  [{'first_name': ' Eva', 'last_name': 'Warns-Pe...      12917
# 37  [{'first_name': ' Shui Shan', 'last_name': 'Le...      12985
# 38  [{'first_name': ' J.', 'last_name': 'Korte', '...        103
# 39  [{'first_name': ' Gillian D', 'last_name': 'Al...      12917
# 40  [{'first_name': ' Colin', 'last_name': 'Robert...      12942
# 41  [{'first_name': ' David J', 'last_name': 'Savo...      12942
# 42  [{'first_name': ' Leslie P.', 'last_name': 'Fr...      11673
# 43  [{'first_name': ' Farzad', 'last_name': 'Mosta...      11524
# 44  [{'first_name': ' Weng-Keen', 'last_name': 'Wo...      11524
# 45  [{'first_name': ' Julie A.', 'last_name': 'Pav...      11524
# 46  [{'first_name': ' Daniel M.', 'last_name': 'So...      11524
#
#                                           journalName meshterms  \
# 0                                        BMC Medicine        []
# 1                             BMC Veterinary Research        []
# 2                                   BMC Public Health        []
# 3                                   BMC Public Health        []
# 4                             BMC Veterinary Research        []
# 5                                  BMC Research Notes        []
# 6         Flexible Services and Manufacturing Journal        []
# 7                                 Parasites & Vectors        []
# 8                 Data Mining and Knowledge Discovery        []
# 9                              BMC Emergency Medicine        []
# 10                                  BMC Public Health        []
# 11                                          EcoHealth        []
# 12                                  BMC Public Health        []
# 13                       BMC Health Services Research        []
# 14        BMC Medical Informatics and Decision Making        []
# 15                        KI - Künstliche Intelligenz        []
# 16                            BMC Infectious Diseases        []
# 17              Tropical Animal Health and Production        []
# 18      Bulletin de la Société de pathologie exotique        []
# 19        BMC Medical Informatics and Decision Making        []
# 20                            BMC Infectious Diseases        []
# 21                    Journal of Public Health Policy        []
# 22                            BMC Infectious Diseases        []
# 23                            BMC Veterinary Research        []
# 24                            BMC Veterinary Research        []
# 25                               Environmental Health        []
# 26                                  BMC Public Health        []
# 27        BMC Medical Informatics and Decision Making        []
# 28                            BMC Veterinary Research        []
# 29        BMC Medical Informatics and Decision Making        []
# 30                                  BMC Public Health        []
# 31                            BMC Veterinary Research        []
# 32        BMC Medical Informatics and Decision Making        []
# 33                               Environmental Health        []
# 34                                    BMC Proceedings        []
# 35                                 BMC Research Notes        []
# 36                            BMC Veterinary Research        []
# 37                                   Virology Journal        []
# 38  Bundesgesundheitsblatt - Gesundheitsforschung ...        []
# 39                            BMC Veterinary Research        []
# 40        International Journal of Health Geographics        []
# 41        International Journal of Health Geographics        []
# 42                      Journal of Bioethical Inquiry        []
# 43                            Journal of Urban Health        []
# 44                            Journal of Urban Health        []
# 45                            Journal of Urban Health        []
# 46                            Journal of Urban Health        []
#
#                   optionalId01 optionalId02 publishdate publishdatefull  \
# 0    10.1186/s12916-018-1015-9    1741-7015        None      2018-03-19
# 1    10.1186/s12917-017-1292-0    1746-6148        None      2017-11-29
# 2    10.1186/s12889-017-4372-y    1471-2458        None      2017-05-19
# 3    10.1186/s12889-017-4233-8    1471-2458        None      2017-04-18
# 4    10.1186/s12917-016-0914-2    1746-6148        None      2016-12-20
# 5    10.1186/s13104-016-2098-z    1756-0500        None      2016-06-18
# 6    10.1007/s10696-014-9204-0    1936-6590        None      2016-06-01
# 7    10.1186/s13071-016-1590-6    1756-3305        None      2016-05-23
# 8    10.1007/s10618-015-0434-x    1573-756X        None      2016-05-01
# 9    10.1186/s12873-016-0080-7    1471-227X        None      2016-03-09
# 10   10.1186/s12889-015-2680-7    1471-2458        None      2016-01-09
# 11   10.1007/s10393-015-1054-z    1612-9210        None      2015-12-01
# 12   10.1186/s12889-015-2475-x    1471-2458        None      2015-11-14
# 13   10.1186/s12913-015-0965-2    1472-6963        None      2015-07-25
# 14   10.1186/s12911-015-0174-2    1472-6947        None      2015-07-15
# 15   10.1007/s13218-015-0349-0    1610-1987        None      2015-06-01
# 16   10.1186/s12879-015-0789-z    1471-2334        None      2015-03-01
# 17   10.1007/s11250-014-0736-9    1573-7438        None      2015-02-01
# 18   10.1007/s13149-014-0390-5    1961-9049        None      2015-02-01
# 19   10.1186/s12911-014-0108-4    1472-6947        None      2014-12-05
# 20   10.1186/s12879-014-0604-2    1471-2334        None      2014-11-18
# 21        10.1057/jphp.2014.13    1745-655X        None      2014-08-01
# 22    10.1186/1471-2334-14-381    1471-2334        None      2014-07-10
# 23     10.1186/1746-6148-10-33    1746-6148        None      2014-01-31
# 24     10.1186/1746-6148-9-231    1746-6148        None      2013-11-18
# 25     10.1186/1476-069X-12-94    1476-069X        None      2013-11-05
# 26    10.1186/1471-2458-13-905    1471-2458        None      2013-10-01
# 27    10.1186/1472-6947-13-101    1472-6947        None      2013-09-03
# 28      10.1186/1746-6148-9-88    1746-6148        None      2013-04-30
# 29     10.1186/1472-6947-13-40    1472-6947        None      2013-03-28
# 30    10.1186/1471-2458-12-929    1471-2458        None      2012-10-30
# 31     10.1186/1746-6148-8-192    1746-6148        None      2012-10-16
# 32      10.1186/1472-6947-12-4    1472-6947        None      2012-02-03
# 33      10.1186/1476-069X-11-3    1476-069X        None      2012-01-24
# 34  10.1186/1753-6561-5-S6-P33    1753-6561        None      2011-06-29
# 35     10.1186/1756-0500-4-187    1756-0500        None      2011-06-14
# 36      10.1186/1746-6148-6-56    1746-6148        None      2010-12-16
# 37     10.1186/1743-422X-7-321    1743-422X        None      2010-11-16
# 38   10.1007/s00103-010-1117-9    1437-1588        None      2010-09-01
# 39      10.1186/1746-6148-6-42    1746-6148        None      2010-08-12
# 40      10.1186/1476-072X-9-16    1476-072X        None      2010-03-12
# 41       10.1186/1476-072X-9-1    1476-072X        None      2010-01-18
# 42   10.1007/s11673-009-9163-4    1872-4353        None      2009-06-01
# 43          10.1007/PL00022314    1468-2869        None      2003-03-01
# 44          10.1007/PL00022317    1468-2869        None      2003-03-01
# 45          10.1007/PL00022321    1468-2869        None      2003-03-01
# 46          10.1007/PL00022309    1468-2869        None      2003-03-01
#
#                pubtype pullsource  \
# 0        OriginalPaper   springer
# 1        OriginalPaper   springer
# 2        OriginalPaper   springer
# 3        OriginalPaper   springer
# 4        OriginalPaper   springer
# 5        OriginalPaper   springer
# 6        OriginalPaper   springer
# 7        OriginalPaper   springer
# 8        OriginalPaper   springer
# 9        OriginalPaper   springer
# 10       OriginalPaper   springer
# 11         ReviewPaper   springer
# 12       OriginalPaper   springer
# 13       OriginalPaper   springer
# 14       OriginalPaper   springer
# 15       OriginalPaper   springer
# 16       OriginalPaper   springer
# 17  BriefCommunication   springer
# 18       OriginalPaper   springer
# 19       OriginalPaper   springer
# 20       OriginalPaper   springer
# 21       OriginalPaper   springer
# 22       OriginalPaper   springer
# 23       OriginalPaper   springer
# 24       OriginalPaper   springer
# 25       OriginalPaper   springer
# 26       OriginalPaper   springer
# 27       OriginalPaper   springer
# 28       OriginalPaper   springer
# 29       OriginalPaper   springer
# 30       OriginalPaper   springer
# 31       OriginalPaper   springer
# 32       OriginalPaper   springer
# 33       OriginalPaper   springer
# 34            Abstract   springer
# 35              Report   springer
# 36       OriginalPaper   springer
# 37              Report   springer
# 38       OriginalPaper   springer
# 39       OriginalPaper   springer
# 40         ReviewPaper   springer
# 41       OriginalPaper   springer
# 42       OriginalPaper   springer
# 43       OriginalPaper   springer
# 44       OriginalPaper   springer
# 45       OriginalPaper   springer
# 46       OriginalPaper   springer
#
#                                                 title
# 0   Clinical assessment is a neglected component o...
# 1   Syndromic surveillance for West Nile virus usi...
# 2   Correcting for day of the week and public holi...
# 3   Early outbreak detection by linking health adv...
# 4   Methodological challenges to multivariate synd...
# 5   SCM: a practical tool to implement hospital-ba...
# 6   Combining syndromic surveillance and ILI data ...
# 7   Use of big data in the surveillance of veterin...
# 8   Syndromic surveillance of Flu on Twitter using...
# 9   Human temperatures for syndromic surveillance ...
# 10  The usefulness of school-based syndromic surve...
# 11  Citizen Science and Wildlife Disease Surveillance
# 12  A cost-effectiveness analysis of three compone...
# 13  Measuring costs of data collection at village ...
# 14  Automatic classification of diseases from free...
# 15   Sensemaking in Intelligent Health Data Analytics
# 16  Assessing the use of hospital staff influenza-...
# 17  Syndromic surveillance of peste des petits rum...
# 18  Renforcement du réseau de surveillance sentine...
# 19  A Bayesian spatio–temporal approach for real–t...
# 20  Drug sales data analysis for outbreak detectio...
# 21  Non-infectious events under the International ...
# 22  Can epidemic detection systems at the hospital...
# 23  Evaluation of Swiss slaughterhouse data for in...
# 24  Comparison of covariate adjustment methods usi...
# 25  Modeling acute respiratory illness during the ...
# 26  Validity and timeliness of syndromic influenza...
# 27  Evaluation of syndromic algorithms for detecti...
# 28  Defining syndromes using cattle meat inspectio...
# 29  Relationship between the population incidence ...
# 30  The use of syndromic surveillance for decision...
# 31  Identifying an outbreak of a novel swine disea...
# 32  Establishing a web-based integrated surveillan...
# 33  Emergency department visits, ambulance calls, ...
# 34  Developing proxy indicators of healthcare asso...
# 35  Perceived usefulness of a distributed communit...
# 36  Unsupervised clustering of wildlife necropsy d...
# 37  Reconstruction of epidemic curves for pandemic...
# 38  Validierung einer syndromischen Surveillance a...
# 39  Factors associated with whole carcass condemna...
# 40  Review of software for space-time disease surv...
# 41  Enhancing spatial detection accuracy for syndr...
# 42  Syndromic Surveillance and Patients as Victims...
# 43  Use of ambulance dispatch data as an early war...
# 44         Wsare: What’s strange about recent events?
# 45  Investigation of disease outbreaks detected by...
# 46  Draft framework for evaluating syndromic surve...

# %%
cur.execute("SELECT pullsource, associatedid from public.datapull_detail")
unique_id_list = cur.fetchall()

# %%
unique_id_list
# Out:
# [('pubmed', '27317431'),
#  ('pubmed', '26957967'),
#  ('pubmed', '29122738'),
#  ('pubmed', '25889382'),
#  ('pubmed', '27641930'),
#  ('pubmed', '21924796'),
#  ('pubmed', '27938434'),
#  ('pubmed', '27118150'),
#  ('pubmed', '28543608'),
#  ('pubmed', '28692394'),
#  ('pubmed', '28692394'),
#  ('pubmed', '25065517'),
#  ('pubmed', '26415918'),
#  ('pubmed', '28692384'),
#  ('pubmed', '28692388'),
#  ('pubmed', '24058494'),
#  ('pubmed', '28188203'),
#  ('pubmed', '28692391'),
#  ('pubmed', '28543608'),
#  ('pubmed', '22366039'),
#  ('pubmed', '27641930'),
#  ('pubmed', '28692397'),
#  ('pubmed', '26883318'),
#  ('pubmed', '28692387'),
#  ('pubmed', '23620543'),
#  ('pubmed', '19350960'),
#  ('pubmed', '28692400'),
#  ('pubmed', '21339818'),
#  ('pubmed', '24228684'),
#  ('pubmed', '26961277'),
#  ('pubmed', '28945179'),
#  ('pubmed', '24480399'),
#  ('pubmed', '28202020'),
#  ('pubmed', '25723956'),
#  ('pubmed', '27747743'),
#  ('pubmed', '28692401'),
#  ('pubmed', '28760171'),
#  ('pubmed', '24476632'),
#  ('pubmed', '22596079'),
#  ('pubmed', '26072973'),
#  ('pubmed', '26956114'),
#  ('pubmed', '28430095'),
#  ('pubmed', '17299325'),
#  ('pubmed', '17370967'),
#  ('pubmed', '21592398'),
#  ('pubmed', '15986027'),
#  ('pubmed', '24551413'),
#  ('pubmed', '24083852'),
#  ('pubmed', '21705297'),
#  ('pubmed', '21798029'),
#  ('pubmed', '27989247'),
#  ('pubmed', '24274126'),
#  ('pubmed', '19630852'),
#  ('pubmed', '21090186'),
#  ('pubmed', '28692396'),
#  ('pubmed', '26784214'),
#  ('pubmed', '28586627'),
#  ('pubmed', '25245567'),
#  ('pubmed', '24099832'),
#  ('pubmed', '18201388'),
#  ('pubmed', '27146906'),
#  ('pubmed', '23700370'),
#  ('pubmed', '24421826'),
#  ('pubmed', '27786390'),
#  ('pubmed', '25406040'),
#  ('pubmed', '16177711'),
#  ('pubmed', '18664727'),
#  ('pubmed', '26873949'),
#  ('pubmed', '21818437'),
#  ('pubmed', '15717390'),
#  ('pubmed', '28692390'),
#  ('pubmed', '28692389'),
#  ('pubmed', '25828997'),
#  ('pubmed', '29208164'),
#  ('pubmed', '18522311'),
#  ('pubmed', '17238445'),
#  ('pubmed', '22984645'),
#  ('pubmed', '15576514'),
#  ('pubmed', '27068133'),
#  ('pubmed', '26076006'),
#  ('pubmed', '25879869'),
#  ('pubmed', '29045851'),
#  ('pubmed', '28692392'),
#  ('pubmed', '24921898'),
#  ('pubmed', '19743758'),
#  ('pubmed', '24435015'),
#  ('pubmed', '16868239'),
#  ('pubmed', '16380562'),
#  ('pubmed', '27087220'),
#  ('pubmed', '26198105'),
#  ('pubmed', '21647355'),
#  ('pubmed', '27044495'),
#  ('pubmed', '18937875'),
#  ('pubmed', '25725005'),
#  ('pubmed', '25360596'),
#  ('pubmed', '29043764'),
#  ('pubmed', '16235804'),
#  ('pubmed', '22379219'),
#  ('pubmed', '19555611'),
#  ('pubmed', '28409055'),
#  ('pubmed', '15332067'),
#  ('pubmed', '19261941'),
#  ('pubmed', '24044464'),
#  ('pubmed', '22892324'),
#  ('pubmed', '15714630'),
#  ('pubmed', '28338425'),
#  ('pubmed', '28886112'),
#  ('pubmed', '24004720'),
#  ('pubmed', '20825786'),
#  ('pubmed', '23902949'),
#  ('pubmed', '22210640'),
#  ('pubmed', '21645354'),
#  ('pubmed', '21888804'),
#  ('pubmed', '28692402'),
#  ('pubmed', '25875080'),
#  ('pubmed', '15332066'),
#  ('pubmed', '25720820'),
#  ('pubmed', '11919529'),
#  ('pubmed', '23661404'),
#  ('pubmed', '25919375'),
#  ('pubmed', '19232122'),
#  ('pubmed', '27125271'),
#  ('pubmed', '25954453'),
#  ('pubmed', '23616829'),
#  ('pubmed', '16177688'),
#  ('pubmed', '29664375'),
#  ('pubmed', '15717391'),
#  ('pubmed', '18563993'),
#  ('pubmed', '16492494'),
#  ('pubmed', '15253519'),
#  ('pubmed', '12643841'),
#  ('pubmed', '26426119'),
#  ('pubmed', '19943970'),
#  ('pubmed', '24130046'),
#  ('pubmed', '23114239'),
#  ('pubmed', '23777991'),
#  ('pubmed', '23472161'),
#  ('pubmed', '25888865'),
#  ('pubmed', '15714638'),
#  ('pubmed', '25140999'),
#  ('pubmed', '18226314'),
#  ('pubmed', '29034093'),
#  ('pubmed', '12791784'),
#  ('pubmed', '22115045'),
#  ('pubmed', '19383138'),
#  ('pubmed', '22759619'),
#  ('pubmed', '21448581'),
#  ('pubmed', '23537222'),
#  ('pubmed', '15332065'),
#  ('pubmed', '15235376'),
#  ('pubmed', '26767059'),
#  ('pubmed', '28255519'),
#  ('pubmed', '20711252'),
#  ('pubmed', '18782400'),
#  ('pubmed', '19961086'),
#  ('pubmed', '21216033'),
#  ('pubmed', '24804952'),
#  ('pubmed', '19607669'),
#  ('pubmed', '18371248'),
#  ('pubmed', '16750306'),
#  ('pubmed', '15743535'),
#  ('pubmed', '20028535'),
#  ('pubmed', '23154104'),
#  ('pubmed', '20350382'),
#  ('pubmed', '25046059'),
#  ('pubmed', '17144927'),
#  ('pubmed', '22010543'),
#  ('pubmed', '21889615'),
#  ('pubmed', '15714635'),
#  ('pubmed', '12658241'),
#  ('pubmed', '18999051'),
#  ('pubmed', '19851578'),
#  ('pubmed', '12791782'),
#  ('pubmed', '21857229'),
#  ('pubmed', '15200820'),
#  ('pubmed', '12791779'),
#  ('pubmed', '15717394'),
#  ('pubmed', '19635001'),
#  ('pubmed', '28877241'),
#  ('pubmed', '17992102'),
#  ('pubmed', '17928273'),
#  ('pubmed', '21913587'),
#  ('pubmed', '19722336'),
#  ('pubmed', '28574193'),
#  ('pubmed', '16841501'),
#  ('pubmed', '29623242'),
#  ('pubmed', '29094343'),
#  ('pubmed', '25844373'),
#  ('pubmed', '12238536'),
#  ('pubmed', '22790605'),
#  ('pubmed', '15167186'),
#  ('pubmed', '28701374'),
#  ('pubmed', '15179142'),
#  ('pubmed', '16372902'),
#  ('pubmed', '19025683'),
#  ('pubmed', '21402825'),
#  ('pubmed', '16480500'),
#  ('pubmed', '27314657'),
#  ('pubmed', '17018828'),
#  ('pubmed', '16023563'),
#  ('pubmed', '12542838'),
#  ('pubmed', '25914856'),
#  ('pubmed', '17877836'),
#  ('pubmed', '17484301'),
#  ('pubmed', '27772674'),
#  ('pubmed', '16271676'),
#  ('pubmed', '28692393'),
#  ('pubmed', '9832668'),
#  ('pubmed', '14728233'),
#  ('pubmed', '18813679'),
#  ('pubmed', '11875797'),
#  ('pubmed', '19320369'),
#  ('pubmed', '15714637'),
#  ('pubmed', '28226020'),
#  ('pubmed', '15714622'),
#  ('pubmed', '19952883'),
#  ('pubmed', '27770712'),
#  ('pubmed', '20051540'),
#  ('pubmed', '28692386'),
#  ('pubmed', '7661427'),
#  ('pubmed', '14985670'),
#  ('pubmed', '28057113'),
#  ('pubmed', '22693719'),
#  ('pubmed', '19491582'),
#  ('pubmed', '17433157'),
#  ('pubmed', '26880489'),
#  ('pubmed', '20853587'),
#  ('pubmed', '17567912'),
#  ('pubmed', '20411066'),
#  ('pubmed', '17919318'),
#  ('pubmed', '24599798'),
#  ('pubmed', '20496562'),
#  ('pubmed', '25463924'),
#  ('pubmed', '18036253'),
#  ('pubmed', '26367788'),
#  ('pubmed', '23860988'),
#  ('pubmed', '22361231'),
#  ('pubmed', '12463844'),
#  ('pubmed', '19515246'),
#  ('pubmed', '21894257'),
#  ('pubmed', '19013376'),
#  ('pubmed', '24659490'),
#  ('pubmed', '21621359'),
#  ('pubmed', '19170788'),
#  ('pubmed', '19402974'),
#  ('pubmed', '22996883'),
#  ('pubmed', '29217768'),
#  ('pubmed', '19697412'),
#  ('pubmed', '11073481'),
#  ('pubmed', '26675375'),
#  ('pubmed', '24059251'),
#  ('pubmed', '25517353'),
#  ('pubmed', '19682027'),
#  ('pubmed', '20540003'),
#  ('pubmed', '24331080'),
#  ('pubmed', '20473464'),
#  ('pubmed', '26658339'),
#  ('pubmed', '23965831'),
#  ('pubmed', '14531222'),
#  ('pubmed', '18693881'),
#  ('pubmed', '17328822'),
#  ('pubmed', '16177706'),
#  ('pubmed', '23530722'),
#  ('pubmed', '20805613'),
#  ('pubmed', '29026453'),
#  ('pubmed', '12350450'),
#  ('pubmed', '27179935'),
#  ('pubmed', '12491756'),
#  ('pubmed', '17955008'),
#  ('pubmed', '19000956'),
#  ('pubmed', '10726649'),
#  ('pubmed', '26083183'),
#  ('pubmed', '19214876'),
#  ('pubmed', '29422011'),
#  ('pubmed', '23825164'),
#  ('pubmed', '12605212'),
#  ('pubmed', '16177695'),
#  ('pubmed', '15717395'),
#  ('pubmed', '23165813'),
#  ('pubmed', '12613100'),
#  ('pubmed', '18693934'),
#  ('pubmed', '20853588'),
#  ('pubmed', '15969749'),
#  ('pubmed', '17600101'),
#  ('pubmed', '22554338'),
#  ('pubmed', '23448272'),
#  ('pubmed', '25379126'),
#  ('pubmed', '26894570'),
#  ('pubmed', '15361005'),
#  ('pubmed', '16679172'),
#  ('pubmed', '29181246'),
#  ('pubmed', '15289627'),
#  ('pubmed', '17959430'),
#  ('pubmed', '17095301'),
#  ('pubmed', '27501302'),
#  ('pubmed', '15139264'),
#  ('pubmed', '21484019'),
#  ('pubmed', '27053920'),
#  ('pubmed', '12880873'),
#  ('pubmed', '10538067'),
#  ('pubmed', '16328705'),
#  ('pubmed', '20938854'),
#  ('pubmed', '19928423'),
#  ('pubmed', '29530470'),
#  ('pubmed', '15259412'),
#  ('pubmed', '16060564'),
#  ('pubmed', '9579149'),
#  ('pubmed', '27517280'),
#  ('pubmed', '20511736'),
#  ('pubmed', '27473947'),
#  ('pubmed', '21096870'),
#  ('pubmed', '18694164'),
#  ('pubmed', '17719678'),
#  ('pubmed', '12224119'),
#  ('pubmed', '29653060'),
#  ('pubmed', '24339927'),
#  ('pubmed', '19797961'),
#  ('pubmed', '26804014'),
#  ('pubmed', '17120488'),
#  ('pubmed', '20170529'),
#  ('pubmed', '15693407'),
#  ('pubmed', '12090835'),
#  ('pubmed', '22180619'),
#  ('pubmed', '19047240'),
#  ('pubmed', '29258648'),
#  ('pubmed', '7865278'),
#  ('pubmed', '18708888'),
#  ('pubmed', '15058094'),
#  ('pubmed', '27876010'),
#  ('pubmed', '21882040'),
#  ('pubmed', '29208134'),
#  ('pubmed', '16177692'),
#  ('pubmed', '19851579'),
#  ('pubmed', '29260662'),
#  ('pubmed', '26822048'),
#  ('pubmed', '22124491'),
#  ('pubmed', '11073468'),
#  ('pubmed', '16773882'),
#  ('pubmed', '27193265'),
#  ('pubmed', '24192051'),
#  ('pubmed', '16177700'),
#  ('pubmed', '12540684'),
#  ('pubmed', '17370964'),
#  ('pubmed', '21335691'),
#  ('pubmed', '11073465'),
#  ('pubmed', '23692155'),
#  ('pubmed', '26834939'),
#  ('pubmed', '19851591'),
#  ('pubmed', '17079790'),
#  ('pubmed', '17806048'),
#  ('pubmed', '12704318'),
#  ('pubmed', '23871405'),
#  ('pubmed', '26082289'),
#  ('pubmed', '28801431'),
#  ('pubmed', '22953242'),
#  ('pubmed', '15553525'),
#  ('pubmed', '15454888'),
#  ('pubmed', '23169406'),
#  ('pubmed', '28468055'),
#  ('pubmed', '28542417'),
#  ('pubmed', '19883546'),
#  ('pubmed', '17238563'),
#  ('pubmed', '29397949'),
#  ('pubmed', '18284356'),
#  ('pubmed', '16416696'),
#  ('pubmed', '15064782'),
#  ('pubmed', '29628149'),
#  ('pubmed', '22029484'),
#  ('pubmed', '15597906'),
#  ('pubmed', '28180277'),
#  ('pubmed', '18047750'),
#  ('pubmed', '15714636'),
#  ('pubmed', '24884489'),
#  ('pubmed', '11585525'),
#  ('pubmed', '27640813'),
#  ('pubmed', '14579767'),
#  ('pubmed', '12492760'),
#  ('pubmed', '18767420'),
#  ('pubmed', '12221919'),
#  ('pubmed', '22189398'),
#  ('pubmed', '14655231'),
#  ('pubmed', '11392171'),
#  ('pubmed', '17220495'),
#  ('pubmed', '25835538'),
#  ('pubmed', '12619456'),
#  ('pubmed', '24343613'),
#  ('pubmed', '15958929'),
#  ('pubmed', '18819677'),
#  ('pubmed', '17717513'),
#  ('pubmed', '15551856'),
#  ('pubmed', '15060861'),
#  ('pubmed', '19307149'),
#  ('pubmed', '16498157'),
#  ('pubmed', '17762687'),
#  ('pubmed', '28072669'),
#  ('pubmed', '19716433'),
#  ('pubmed', '21211339'),
#  ('pubmed', '18090202'),
#  ('pubmed', '10181123'),
#  ('pubmed', '15946768'),
#  ('pubmed', '22242207'),
#  ('pubmed', '21211054'),
#  ('pubmed', '26218274'),
#  ('pubmed', '16177704'),
#  ('pubmed', '17076426'),
#  ('pubmed', '20521494'),
#  ('pubmed', '11588914'),
#  ('pubmed', '10349214'),
#  ('pubmed', '23457520'),
#  ('pubmed', '7491561'),
#  ('pubmed', '10710019'),
#  ('pubmed', '10182312'),
#  ('pubmed', '12791777'),
#  ('pubmed', '25222207'),
#  ('pubmed', '15939854'),
#  ('pubmed', '24840742'),
#  ('pubmed', '25955521'),
#  ('pubmed', '11045405'),
#  ('pubmed', '9744681'),
#  ('pubmed', '18251730'),
#  ('pubmed', '12244930'),
#  ('pubmed', '15231924'),
#  ('pubmed', '28646879'),
#  ('pubmed', '12226115'),
#  ('pubmed', '28007397'),
#  ('pubmed', '27867737'),
#  ('pubmed', '26635815'),
#  ('pubmed', '22015064'),
#  ('pubmed', '20661275'),
#  ('pubmed', '15622795'),
#  ('pubmed', '22080661'),
#  ('pubmed', '18664725'),
#  ('pubmed', '28601216'),
#  ('pubmed', '10907903'),
#  ('pubmed', '17718007'),
#  ('pubmed', '25045587'),
#  ('pubmed', '15150390'),
#  ('pubmed', '22547862'),
#  ('pubmed', '24975977'),
#  ('pubmed', '27033409'),
#  ('pubmed', '22589573'),
#  ('pubmed', '28961606'),
#  ('pubmed', '27766181'),
#  ('pubmed', '27182731'),
#  ('pubmed', '22817479'),
#  ('pubmed', '25597940'),
#  ('pubmed', '22823595'),
#  ('pubmed', '28586629'),
#  ('pubmed', '19197389'),
#  ('pubmed', '28246576'),
#  ('pubmed', '24001609'),
#  ('pubmed', '24618105'),
#  ('pubmed', '27998276'),
#  ('pubmed', '22325010'),
#  ('pubmed', '25074591'),
#  ('pubmed', '17564110'),
#  ('pubmed', '28666433'),
#  ('pubmed', '26927901'),
#  ('pubmed', '23396181'),
#  ('pubmed', '26212144'),
#  ('pubmed', '26310340'),
#  ('pubmed', '27670151'),
#  ('pubmed', '29158208'),
#  ('pubmed', '25928866'),
#  ('pubmed', '26732291'),
#  ('pubmed', '27440281'),
#  ('pubmed', '19551241'),
#  ('pubmed', '26230666'),
#  ('pubmed', '23997308'),
#  ('pubmed', '28779435'),
#  ('pubmed', '25239536'),
#  ('pubmed', '23626853'),
#  ('pubmed', '25617916'),
#  ('pubmed', '24613716'),
#  ('pubmed', '19491585'),
#  ('pubmed', '27125552'),
#  ('pubmed', '25699182'),
#  ('pubmed', '24955962'),
#  ('pubmed', '19369852'),
#  ('pubmed', '29138128'),
#  ('pubmed', '28830105'),
#  ('pubmed', '28079746'),
#  ('pubmed', '22291929'),
#  ('pubmed', '25433648'),
#  ('pubmed', '17238340'),
#  ('pubmed', '25100179'),
#  ('pubmed', '24524234'),
#  ('pubmed', '23798720'),
#  ('pubmed', '24028074'),
#  ('pubmed', '22397597'),
#  ('pubmed', '23581956'),
#  ('pubmed', '20213323'),
#  ('pubmed', '22615893'),
#  ('pubmed', '23399422'),
#  ('pubmed', '21401456'),
#  ('pubmed', '23169970'),
#  ('pubmed', '21292718'),
#  ('pubmed', '21791092'),
#  ('pubmed', '23169976'),
#  ('pubmed', '22874371'),
#  ('pubmed', '29465702'),
#  ('pubmed', '21162732'),
#  ('pubmed', '22360741'),
#  ('pubmed', '20578488'),
#  ('pubmed', '11974883'),
#  ('pubmed', '22754248'),
#  ('pubmed', '17991385'),
#  ('pubmed', '22093471'),
#  ('pubmed', '18396666'),
#  ('pubmed', '17991396'),
#  ('pubmed', '20799563'),
#  ('pubmed', '29395844'),
#  ('pubmed', '28138938'),
#  ('pubmed', '20826636'),
#  ('pubmed', '20885183'),
#  ('pubmed', '21668678'),
#  ('pubmed', '20118677'),
#  ('pubmed', '21108871'),
#  ('pubmed', '26055920'),
#  ('pubmed', '21887216'),
#  ('pubmed', '21473803'),
#  ('pubmed', '20043603'),
#  ('pubmed', '21283815'),
#  ('pubmed', '27398361'),
#  ('pubmed', '26505620'),
#  ('pubmed', '23883362'),
#  ('pubmed', '17130655'),
#  ('pubmed', '29590162'),
#  ('pubmed', '18413353'),
#  ('pubmed', '25567701'),
#  ('pubmed', '17331250'),
#  ('pubmed', '26975056'),
#  ('pubmed', '29140229'),
#  ('pubmed', '25844366'),
#  ('pubmed', '27902653'),
#  ('pubmed', '26708405'),
#  ('pubmed', '25865518'),
#  ('pubmed', '16220859'),
#  ('pubmed', '27188367'),
#  ('pubmed', '16177690'),
#  ('pubmed', '26174895'),
#  ('pubmed', '23990096'),
#  ('pubmed', '17089946'),
#  ('pubmed', '12192166'),
#  ('pubmed', '26806005'),
#  ('pubmed', '26584168'),
#  ('pubmed', '25483540'),
#  ('pubmed', '17216592'),
#  ('pubmed', '17899399'),
#  ('pubmed', '26930941'),
#  ('pubmed', '28422004'),
#  ('pubmed', '23169978'),
#  ('pubmed', '25490948'),
#  ('pubmed', '25655053'),
#  ('pubmed', '28043227'),
#  ('pubmed', '29208131'),
#  ('pubmed', '28786124'),
#  ('pubmed', '10858716'),
#  ('pubmed', '25726431'),
#  ('pubmed', '26184659'),
#  ('pubmed', '16061532'),
#  ('pubmed', '20841725'),
#  ('pubmed', '25024246'),
#  ('pubmed', '23507660'),
#  ('pubmed', '29088290'),
#  ('pubmed', '18637078'),
#  ('pubmed', '27391232'),
#  ('pubmed', '28934439'),
#  ('pubmed', '27353588'),
#  ('pubmed', '12891071'),
#  ('pubmed', '15106115'),
#  ('pubmed', '17089947'),
#  ('pubmed', '22305256'),
#  ('pubmed', '25222208'),
#  ('pubmed', '28237235'),
#  ('pubmed', '23800243'),
#  ('pubmed', '24162504'),
#  ('pubmed', '26062645'),
#  ('pubmed', '27494798'),
#  ('pubmed', '22452874'),
#  ('pubmed', '24890961'),
#  ('pubmed', '27208635'),
#  ('pubmed', '22296733'),
#  ('pubmed', '21135655'),
#  ('pubmed', '23498987'),
#  ('pubmed', '27301964'),
#  ('pubmed', '27902900'),
#  ('pubmed', '29152890'),
#  ('pubmed', '28141670'),
#  ('pubmed', '27099891'),
#  ('pubmed', '25511881'),
#  ('pubmed', '27821217'),
#  ('pubmed', '28653119'),
#  ('pubmed', '27418404'),
#  ('pubmed', '27281020'),
#  ('pubmed', '26353460'),
#  ('pubmed', '15040204'),
#  ('pubmed', '29513661'),
#  ('pubmed', '16891497'),
#  ('pubmed', '24903503'),
#  ('pubmed', '22218580'),
#  ('pubmed', '24746609'),
#  ('pubmed', '25955837'),
#  ('pubmed', '24099871'),
#  ('pubmed', '24566788'),
#  ('pubmed', '22804843'),
#  ('pubmed', '29522133'),
#  ('pubmed', '24736452'),
#  ('pubmed', '25141887'),
#  ('pubmed', '28332648'),
#  ('pubmed', '18977544'),
#  ('pubmed', '19931724'),
#  ('pubmed', '24377388'),
#  ('pubmed', '25013978'),
#  ('pubmed', '22813389'),
#  ('pubmed', '21486880'),
#  ('pubmed', '25164596'),
#  ('pubmed', '20041114'),
#  ('pubmed', '23327375'),
#  ('pubmed', '25748641'),
#  ('pubmed', '20703703'),
#  ('pubmed', '27738704'),
#  ('pubmed', '21886791'),
#  ('pubmed', '22740530'),
#  ('pubmed', '27856384'),
#  ('pubmed', '22776734'),
#  ('pubmed', '19269992'),
#  ('pubmed', '25415728'),
#  ('pubmed', '22536579'),
#  ('pubmed', '20519260'),
#  ('pubmed', '23475302'),
#  ('pubmed', '28274300'),
#  ('pubmed', '20459679'),
#  ('pubmed', '24069267'),
#  ('pubmed', '21036853'),
#  ('pubmed', '24155907'),
#  ('pubmed', '20851086'),
#  ('pubmed', '19479875'),
#  ('pubmed', '24793950'),
#  ('pubmed', '21788780'),
#  ('pubmed', '25732682'),
#  ('pubmed', '27762211'),
#  ('pubmed', '23478583'),
#  ('pubmed', '24968153'),
#  ('pubmed', '26850248'),
#  ('pubmed', '19589619'),
#  ('pubmed', '25996366'),
#  ('pubmed', '24679719'),
#  ('pubmed', '25448093'),
#  ('pubmed', '26782751'),
#  ('pubmed', '18284368'),
#  ('pubmed', '27504965'),
#  ('pubmed', '21219718'),
#  ('pubmed', '23996607'),
#  ('pubmed', '22265643'),
#  ('pubmed', '28973011'),
#  ('pubmed', '21309448'),
#  ('pubmed', '23373256'),
#  ('pubmed', '22233476'),
#  ('pubmed', '27677310'),
#  ('pubmed', '17433201'),
#  ('pubmed', '21408127'),
#  ('pubmed', '20307266'),
#  ('pubmed', '19645759'),
#  ('pubmed', '27607330'),
#  ('pubmed', '25677052'),
#  ('pubmed', '27863513'),
#  ('pubmed', '25465259'),
#  ('pubmed', '21563923'),
#  ('pubmed', '27475474'),
#  ('pubmed', '21377747'),
#  ('pubmed', '22642945'),
#  ('pubmed', '26165434'),
#  ('pubmed', '15966677'),
#  ('pubmed', '25476882'),
#  ('pubmed', '26822602'),
#  ('pubmed', '21705905'),
#  ('pubmed', '20633960'),
#  ('pubmed', '24637513'),
#  ('pubmed', '27686761'),
#  ('pubmed', '21367769'),
#  ('pubmed', '28040684'),
#  ('pubmed', '11225381'),
#  ('pubmed', '24579468'),
#  ('pubmed', '22129083'),
#  ('pubmed', '25356711'),
#  ('pubmed', '18239339'),
#  ('pubmed', '23211182'),
#  ('pubmed', '23415499'),
#  ('pubmed', '19901383'),
#  ('pubmed', '21532816'),
#  ('pubmed', '20539858'),
#  ('pubmed', '26778420'),
#  ('pubmed', '16501727'),
#  ('pubmed', '21954270'),
#  ('pubmed', '23787129'),
#  ('pubmed', '22804910'),
#  ('pubmed', '20673265'),
#  ('pubmed', '25160359'),
#  ('pubmed', '22299466'),
#  ('pubmed', '22164863'),
#  ('pubmed', '21647308'),
#  ('pubmed', '25074234'),
#  ('pubmed', '25420951'),
#  ('pubmed', '22109868'),
#  ('pubmed', '25875944'),
#  ('pubmed', '25901870'),
#  ('pubmed', '26536167'),
#  ('pubmed', '27720448'),
#  ('pubmed', '25087027'),
#  ('pubmed', '23591102'),
#  ('pubmed', '29095808'),
#  ('pubmed', '22943436'),
#  ('pubmed', '21676986'),
#  ('pubmed', '17931533'),
#  ('pubmed', '26468736'),
#  ('pubmed', '21819293'),
#  ('pubmed', '23432859'),
#  ('pubmed', '21130351'),
#  ('pubmed', '23496887'),
#  ('pubmed', '20955355'),
#  ('pubmed', '25975396'),
#  ('pubmed', '23870515'),
#  ('pubmed', '18374206'),
#  ('pubmed', '25936723'),
#  ('pubmed', '12448866'),
#  ('pubmed', '29551092'),
#  ('pubmed', '20218877'),
#  ('pubmed', '23098821'),
#  ('pubmed', '20402587'),
#  ('pubmed', '25323077'),
#  ('pubmed', '19361875'),
#  ('pubmed', '22087321'),
#  ('pubmed', '26795366'),
#  ('pubmed', '22941822'),
#  ('pubmed', '22991847'),
#  ('pubmed', '29374893'),
#  ('pubmed', '21123522'),
#  ('pubmed', '28159000'),
#  ('pubmed', '19934536'),
#  ('pubmed', '22262595'),
#  ('pubmed', '21629730'),
#  ('pubmed', '20193202'),
#  ('pubmed', '18462148'),
#  ('pubmed', '23449183'),
#  ('pubmed', '22164631'),
#  ('pubmed', '19189835'),
#  ('pubmed', '26654752'),
#  ('pubmed', '18171183'),
#  ('pubmed', '17570859'),
#  ('pubmed', '27219455'),
#  ('pubmed', '21653293'),
#  ('pubmed', '24700557'),
#  ('pubmed', '25193563'),
#  ('pubmed', '19194679'),
#  ('pubmed', '20510059'),
#  ('pubmed', '25521240'),
#  ('pubmed', '16539998'),
#  ('pubmed', '26593706'),
#  ('pubmed', '28992391'),
#  ('pubmed', '16340617'),
#  ('pubmed', '21907985'),
#  ('pubmed', '17354529'),
#  ('pubmed', '18251229'),
#  ('pubmed', '26267430'),
#  ('pubmed', '24253244'),
#  ('pubmed', '22516046'),
#  ('pubmed', '26295485'),
#  ('pubmed', '26922654'),
#  ('pubmed', '28329167'),
#  ('pubmed', '29532543'),
#  ('pubmed', '17081662'),
#  ('pubmed', '22056775'),
#  ('pubmed', '21669006'),
#  ('pubmed', '27612095'),
#  ('pubmed', '21767571'),
#  ('pubmed', '23763775'),
#  ('pubmed', '18631229'),
#  ('pubmed', '27020713'),
#  ('pubmed', '22966741'),
#  ('pubmed', '17540264'),
#  ('pubmed', '24168083'),
#  ('pubmed', '18343180'),
#  ('pubmed', '27882997'),
#  ('pubmed', '25117760'),
#  ('pubmed', '27893080'),
#  ('pubmed', '21438695'),
#  ('pubmed', '25100402'),
#  ('pubmed', '21077378'),
#  ('pubmed', '20839985'),
#  ('pubmed', '20504379'),
#  ('pubmed', '28230524'),
#  ('pubmed', '19042933'),
#  ('pubmed', '18767422'),
#  ('pubmed', '27863468'),
#  ('pubmed', '24993119'),
#  ('pubmed', '17075159'),
#  ('pubmed', '25677874'),
#  ('pubmed', '21495196'),
#  ('pubmed', '19877536'),
#  ('pubmed', '17762698'),
#  ('pubmed', '27016650'),
#  ('pubmed', '25220619'),
#  ('pubmed', '15295122'),
#  ('pubmed', '29427787'),
#  ('pubmed', '23382898'),
#  ('pubmed', '28780553'),
#  ('pubmed', '18424469'),
#  ('pubmed', '15465408'),
#  ('pubmed', '19006975'),
#  ('pubmed', '17577479'),
#  ('pubmed', '21162868'),
#  ('pubmed', '22422125'),
#  ('pubmed', '26065375'),
#  ('pubmed', '28797591'),
#  ('pubmed', '22529988'),
#  ('pubmed', '16765473'),
#  ('pubmed', '20559040'),
#  ('pubmed', '27941976'),
#  ('pubmed', '17223476'),
#  ('pubmed', '23908915'),
#  ('pubmed', '20836802'),
#  ('pubmed', '21379316'),
#  ('pubmed', '12685920'),
#  ('pubmed', '24926040'),
#  ('pubmed', '17482992'),
#  ('pubmed', '18795848'),
#  ('pubmed', '21212144'),
#  ('pubmed', '17958281'),
#  ('pubmed', '19891367'),
#  ('pubmed', '27096958'),
#  ('pubmed', '26132770'),
#  ('pubmed', '27577556'),
#  ('pubmed', '26854911'),
#  ('pubmed', '11800244'),
#  ('pubmed', '24330941'),
#  ('pubmed', '27525375'),
#  ('pubmed', '20834097'),
#  ('pubmed', '28619700'),
#  ('pubmed', '27277013'),
#  ('pubmed', '24324799'),
#  ('pubmed', '20072772'),
#  ('pubmed', '21143831'),
#  ('pubmed', '17848074'),
#  ('pubmed', '17069029'),
#  ('pubmed', '24776527'),
#  ('pubmed', '16827440'),
#  ('pubmed', '17433944'),
#  ('pubmed', '24993715'),
#  ('pubmed', '25501522'),
#  ('pubmed', '25211543'),
#  ('pubmed', '19204350'),
#  ('pubmed', '24556348'),
#  ('pubmed', '25953275'),
#  ('pubmed', '17696853'),
#  ('pubmed', '20644302'),
#  ('pubmed', '23210497'),
#  ('pubmed', '18634502'),
#  ('pubmed', '16011425'),
#  ('pubmed', '22836645'),
#  ('pubmed', '19181427'),
#  ('pubmed', '12829039'),
#  ('pubmed', '27154392'),
#  ('pubmed', '24146603'),
#  ('pubmed', '27862002'),
#  ('pubmed', '17523475'),
#  ('pubmed', '17370966'),
#  ('pubmed', '17129622'),
#  ('pubmed', '25223268'),
#  ('pubmed', '23407466'),
#  ('pubmed', '15925067'),
#  ('pubmed', '28068386'),
#  ('pubmed', '24721537'),
#  ('pubmed', '18258005'),
#  ('pubmed', '24158773'),
#  ('pubmed', '26485296'),
#  ('pubmed', '20615563'),
#  ('pubmed', '16579863'),
#  ('pubmed', '24559503'),
#  ('pubmed', '17326949'),
#  ('pubmed', '11427825'),
#  ('pubmed', '29433471'),
#  ('pubmed', '27891566'),
#  ('pubmed', '15796273'),
#  ('pubmed', '17706448'),
#  ('pubmed', '12737544'),
#  ('pubmed', '24700977'),
#  ('pubmed', '23773590'),
#  ('pubmed', '24626207'),
#  ('pubmed', '16416695'),
#  ('pubmed', '29598967'),
#  ('pubmed', '12974549'),
#  ('pubmed', '21471951'),
#  ('pubmed', '18047685'),
#  ('pubmed', '11326126'),
#  ('pubmed', '28903887'),
#  ('pubmed', '23399425'),
#  ('pubmed', '18399945'),
#  ('pubmed', '17942191'),
#  ('pubmed', '16088792'),
#  ('pubmed', '28205503'),
#  ('pubmed', '21315055'),
#  ('pubmed', '25283265'),
#  ('pubmed', '15631067'),
#  ('pubmed', '20104109'),
#  ('pubmed', '19828051'),
#  ('pubmed', '21325658'),
#  ('pubmed', '21143820'),
#  ('pubmed', '25291888'),
#  ('pubmed', '24952273'),
#  ('pubmed', '23057531'),
#  ('pubmed', '17685449'),
#  ('pubmed', '17239459'),
#  ('pubmed', '20920328'),
#  ('pubmed', '20657738'),
#  ('pubmed', '25448097'),
#  ('pubmed', '25523971'),
#  ('pubmed', '16642762'),
#  ('pubmed', '29019309'),
#  ('pubmed', '14587934'),
#  ('pubmed', '25869892'),
#  ('pubmed', '15861869'),
#  ('pubmed', '17482999'),
#  ('pubmed', '24340122'),
#  ('pubmed', '17193838'),
#  ('pubmed', '21435329'),
#  ('pubmed', '14703782'),
#  ('pubmed', '15108731'),
#  ('pubmed', '27020673'),
#  ('pubmed', '22443191'),
#  ('pubmed', '19883545'),
#  ('pubmed', '27838667'),
#  ('pubmed', '23916548'),
#  ('pubmed', '18344207'),
#  ('pubmed', '16669132'),
#  ('pubmed', '17158710'),
#  ('pubmed', '15862636'),
#  ('pubmed', '16103611'),
#  ('pubmed', '22377231'),
#  ('pubmed', '21130350'),
#  ('pubmed', '25879411'),
#  ('pubmed', '27848201'),
#  ('pubmed', '29465650'),
#  ('pubmed', '22788851'),
#  ('pubmed', '24529265'),
#  ('pubmed', '19025684'),
#  ('pubmed', '21762570'),
#  ('pubmed', '23187012'),
#  ('pubmed', '29113630'),
#  ('pubmed', '23187013'),
#  ('pubmed', '25033051'),
#  ('pubmed', '12194770'),
#  ('pubmed', '28709555'),
#  ('pubmed', '28703705'),
#  ('pubmed', '29208141'),
#  ('pubmed', '28207307'),
#  ('pubmed', '12865616'),
#  ('pubmed', '21090182'),
#  ('pubmed', '25077419'),
#  ('pubmed', '28797322'),
#  ('pubmed', '20442685'),
#  ('pubmed', '26933028'),
#  ('pubmed', '20153351'),
#  ('pubmed', '21668666'),
#  ('pubmed', '26821109'),
#  ('pubmed', '17173527'),
#  ('pubmed', '24433639'),
#  ('pubmed', '12908724'),
#  ('pubmed', '26744009'),
#  ('pubmed', '24578432'),
#  ('pubmed', '16418988'),
#  ('pubmed', '27097481'),
#  ('pubmed', '27631156'),
#  ('pubmed', '28043222'),
#  ('pubmed', '11950209'),
#  ('pubmed', '18976484'),
#  ('pubmed', '25955774'),
#  ('pubmed', '16379626'),
#  ('pubmed', '29453796'),
#  ('pubmed', '25955775'),
#  ('pubmed', '24247291'),
#  ('pubmed', '24556347'),
#  ('pubmed', '26535911'),
#  ('pubmed', '16195695'),
#  ('pubmed', '29019313'),
#  ('pubmed', '27698277'),
#  ('pubmed', '14703783'),
#  ('pubmed', '24780494'),
#  ('pubmed', '22225773'),
#  ('pubmed', '28230523'),
#  ('pubmed', '14684880'),
#  ('pubmed', '25173482'),
#  ('pubmed', '24420916'),
#  ('pubmed', '27097475'),
#  ('pubmed', '28614376'),
#  ('pubmed', '23399423'),
#  ('pubmed', '22164627'),
#  ('pubmed', '11572635'),
#  ('pubmed', '27065000'),
#  ('pubmed', '16981489'),
#  ...]

# %%
[a for a in unique_id_list if a[0] == 'springer']
# Out:
# []

# %%
len(unique_id_list)
# Out:
# 1858

# %%
from datetime import datetime
values_list = []
for index, row in parse_df.iterrows():
    publication_date = row['publishdatefull']
    month = datetime.strptime(publication_date, '%Y-%m-%d').month
    values_list.append((publication_date,month))

# %%
values_list
# Out:
# [('2018-03-19', 3),
#  ('2017-11-29', 11),
#  ('2017-05-19', 5),
#  ('2017-04-18', 4),
#  ('2016-12-20', 12),
#  ('2016-06-18', 6),
#  ('2016-06-01', 6),
#  ('2016-05-23', 5),
#  ('2016-05-01', 5),
#  ('2016-03-09', 3),
#  ('2016-01-09', 1),
#  ('2015-12-01', 12),
#  ('2015-11-14', 11),
#  ('2015-07-25', 7),
#  ('2015-07-15', 7),
#  ('2015-06-01', 6),
#  ('2015-03-01', 3),
#  ('2015-02-01', 2),
#  ('2015-02-01', 2),
#  ('2014-12-05', 12),
#  ('2014-11-18', 11),
#  ('2014-08-01', 8),
#  ('2014-07-10', 7),
#  ('2014-01-31', 1),
#  ('2013-11-18', 11),
#  ('2013-11-05', 11),
#  ('2013-10-01', 10),
#  ('2013-09-03', 9),
#  ('2013-04-30', 4),
#  ('2013-03-28', 3),
#  ('2012-10-30', 10),
#  ('2012-10-16', 10),
#  ('2012-02-03', 2),
#  ('2012-01-24', 1),
#  ('2011-06-29', 6),
#  ('2011-06-14', 6),
#  ('2010-12-16', 12),
#  ('2010-11-16', 11),
#  ('2010-09-01', 9),
#  ('2010-08-12', 8),
#  ('2010-03-12', 3),
#  ('2010-01-18', 1),
#  ('2009-06-01', 6),
#  ('2003-03-01', 3),
#  ('2003-03-01', 3),
#  ('2003-03-01', 3),
#  ('2003-03-01', 3)]

# %%
values_list = []
for index, row in parse_df.iterrows():
        contributor_type = None
        contributor_contact = None
#         unique_id = row['uniqueid']
        auth_count = 0
#         print(row)
        if row['author'] is not None:
            for auth in row['author']:
                print(auth)
#                 auth_count += 1
#                 if auth_count < 4:
#                     values_list.append((unique_id, auth['fname'], auth['lname'], contributor_type,contributor_contact,auth['affl']))
#                 else:
#                     break
# Out:
# {'first_name': ' Amanda M.', 'last_name': 'Rojek', 'contact': None, 'affl': None}
# {'first_name': ' Kassiani', 'last_name': 'Gkolfinopoulou', 'contact': None, 'affl': None}
# {'first_name': ' Apostolos', 'last_name': 'Veizis', 'contact': None, 'affl': None}
# {'first_name': ' Angeliki', 'last_name': 'Lambrou', 'contact': None, 'affl': None}
# {'first_name': ' Lyndsey', 'last_name': 'Castle', 'contact': None, 'affl': None}
# {'first_name': ' Theano', 'last_name': 'Georgakopoulou', 'contact': None, 'affl': None}
# {'first_name': ' Karl', 'last_name': 'Blanchet', 'contact': None, 'affl': None}
# {'first_name': ' Takis', 'last_name': 'Panagiotopoulos', 'contact': None, 'affl': None}
# {'first_name': ' Peter W.', 'last_name': 'Horby', 'contact': None, 'affl': None}
# {'first_name': 'The Epidemic Diseases Research Group field team', 'last_name': None, 'contact': None, 'affl': None}
# {'first_name': ' Alba', 'last_name': 'Ana', 'contact': None, 'affl': None}
# {'first_name': ' M.', 'last_name': 'Perez Andrés', 'contact': None, 'affl': None}
# {'first_name': ' Ponder', 'last_name': 'Julia', 'contact': None, 'affl': None}
# {'first_name': ' Puig', 'last_name': 'Pedro', 'contact': None, 'affl': None}
# {'first_name': ' Wünschmann', 'last_name': 'Arno', 'contact': None, 'affl': None}
# {'first_name': ' Vander Waal', 'last_name': 'Kimberly', 'contact': None, 'affl': None}
# {'first_name': ' Alvarez', 'last_name': 'Julio', 'contact': None, 'affl': None}
# {'first_name': ' Willette', 'last_name': 'Michelle', 'contact': None, 'affl': None}
# {'first_name': ' Elizabeth', 'last_name': 'Buckingham-Jeffery', 'contact': None, 'affl': None}
# {'first_name': ' Roger', 'last_name': 'Morbey', 'contact': None, 'affl': None}
# {'first_name': ' Thomas', 'last_name': 'House', 'contact': None, 'affl': None}
# {'first_name': ' Alex J.', 'last_name': 'Elliot', 'contact': None, 'affl': None}
# {'first_name': ' Sally', 'last_name': 'Harcourt', 'contact': None, 'affl': None}
# {'first_name': ' Gillian E.', 'last_name': 'Smith', 'contact': None, 'affl': None}
# {'first_name': ' Pär', 'last_name': 'Bjelkmar', 'contact': None, 'affl': None}
# {'first_name': ' Anette', 'last_name': 'Hansen', 'contact': None, 'affl': None}
# {'first_name': ' Caroline', 'last_name': 'Schönning', 'contact': None, 'affl': None}
# {'first_name': ' Jakob', 'last_name': 'Bergström', 'contact': None, 'affl': None}
# {'first_name': ' Margareta', 'last_name': 'Löfdahl', 'contact': None, 'affl': None}
# {'first_name': ' Marianne', 'last_name': 'Lebbad', 'contact': None, 'affl': None}
# {'first_name': ' Anders', 'last_name': 'Wallensten', 'contact': None, 'affl': None}
# {'first_name': ' Görel', 'last_name': 'Allestam', 'contact': None, 'affl': None}
# {'first_name': ' Stephan', 'last_name': 'Stenmark', 'contact': None, 'affl': None}
# {'first_name': ' Johan', 'last_name': 'Lindh', 'contact': None, 'affl': None}
# {'first_name': ' Flavie', 'last_name': 'Vial', 'contact': None, 'affl': None}
# {'first_name': ' Wei', 'last_name': 'Wei', 'contact': None, 'affl': None}
# {'first_name': ' Leonhard', 'last_name': 'Held', 'contact': None, 'affl': None}
# {'first_name': ' Chuchu', 'last_name': 'Ye', 'contact': None, 'affl': None}
# {'first_name': ' Zhongjie', 'last_name': 'Li', 'contact': None, 'affl': None}
# {'first_name': ' Yifei', 'last_name': 'Fu', 'contact': None, 'affl': None}
# {'first_name': ' Yajia', 'last_name': 'Lan', 'contact': None, 'affl': None}
# {'first_name': ' Weiping', 'last_name': 'Zhu', 'contact': None, 'affl': None}
# {'first_name': ' Dinglun', 'last_name': 'Zhou', 'contact': None, 'affl': None}
# {'first_name': ' Honglong', 'last_name': 'Zhang', 'contact': None, 'affl': None}
# {'first_name': ' Shengjie', 'last_name': 'Lai', 'contact': None, 'affl': None}
# {'first_name': ' David L.', 'last_name': 'Buckeridge', 'contact': None, 'affl': None}
# {'first_name': ' Qiao', 'last_name': 'Sun', 'contact': None, 'affl': None}
# {'first_name': ' Weizhong', 'last_name': 'Yang', 'contact': None, 'affl': None}
# {'first_name': ' Taesik', 'last_name': 'Lee', 'contact': None, 'affl': None}
# {'first_name': ' Hayong', 'last_name': 'Shin', 'contact': None, 'affl': None}
# {'first_name': ' Vanina', 'last_name': 'Guernier', 'contact': None, 'affl': None}
# {'first_name': ' Gabriel J.', 'last_name': 'Milinovich', 'contact': None, 'affl': None}
# {'first_name': ' Marcos Antonio', 'last_name': 'Bezerra Santos', 'contact': None, 'affl': None}
# {'first_name': ' Mark', 'last_name': 'Haworth', 'contact': None, 'affl': None}
# {'first_name': ' Glen', 'last_name': 'Coleman', 'contact': None, 'affl': None}
# {'first_name': ' Ricardo J.', 'last_name': 'Soares Magalhaes', 'contact': None, 'affl': None}
# {'first_name': ' Liangzhe', 'last_name': 'Chen', 'contact': None, 'affl': None}
# {'first_name': ' K. S. M.', 'last_name': 'Tozammel Hossain', 'contact': None, 'affl': None}
# {'first_name': ' Patrick', 'last_name': 'Butler', 'contact': None, 'affl': None}
# {'first_name': ' Naren', 'last_name': 'Ramakrishnan', 'contact': None, 'affl': None}
# {'first_name': ' B. Aditya', 'last_name': 'Prakash', 'contact': None, 'affl': None}
# {'first_name': ' Samantha F.', 'last_name': 'Bordonaro', 'contact': None, 'affl': None}
# {'first_name': ' Daniel C.', 'last_name': 'McGillicuddy', 'contact': None, 'affl': None}
# {'first_name': ' Francesco', 'last_name': 'Pompei', 'contact': None, 'affl': None}
# {'first_name': ' Dmitriy', 'last_name': 'Burmistrov', 'contact': None, 'affl': None}
# {'first_name': ' Charles', 'last_name': 'Harding', 'contact': None, 'affl': None}
# {'first_name': ' Leon D.', 'last_name': 'Sanchez', 'contact': None, 'affl': None}
# {'first_name': ' Ruth A.', 'last_name': 'Ashton', 'contact': None, 'affl': None}
# {'first_name': ' Takele', 'last_name': 'Kefyalew', 'contact': None, 'affl': None}
# {'first_name': ' Esey', 'last_name': 'Batisso', 'contact': None, 'affl': None}
# {'first_name': ' Tessema', 'last_name': 'Awano', 'contact': None, 'affl': None}
# {'first_name': ' Zelalem', 'last_name': 'Kebede', 'contact': None, 'affl': None}
# {'first_name': ' Gezahegn', 'last_name': 'Tesfaye', 'contact': None, 'affl': None}
# {'first_name': ' Tamiru', 'last_name': 'Mesele', 'contact': None, 'affl': None}
# {'first_name': ' Sheleme', 'last_name': 'Chibsa', 'contact': None, 'affl': None}
# {'first_name': ' Richard', 'last_name': 'Reithinger', 'contact': None, 'affl': None}
# {'first_name': ' Simon J.', 'last_name': 'Brooker', 'contact': None, 'affl': None}
# {'first_name': ' Becki', 'last_name': 'Lawson', 'contact': None, 'affl': None}
# {'first_name': ' Silviu O.', 'last_name': 'Petrovan', 'contact': None, 'affl': None}
# {'first_name': ' Andrew A.', 'last_name': 'Cunningham', 'contact': None, 'affl': None}
# {'first_name': ' Yan', 'last_name': 'Ding', 'contact': None, 'affl': None}
# {'first_name': ' Rainer', 'last_name': 'Sauerborn', 'contact': None, 'affl': None}
# {'first_name': ' Biao', 'last_name': 'Xu', 'contact': None, 'affl': None}
# {'first_name': ' Nie', 'last_name': 'Shaofa', 'contact': None, 'affl': None}
# {'first_name': ' Weirong', 'last_name': 'Yan', 'contact': None, 'affl': None}
# {'first_name': ' Vinod K.', 'last_name': 'Diwan', 'contact': None, 'affl': None}
# {'first_name': ' Hengjin', 'last_name': 'Dong', 'contact': None, 'affl': None}
# {'first_name': ' Yan', 'last_name': 'Ding', 'contact': None, 'affl': None}
# {'first_name': ' Yang', 'last_name': 'Fei', 'contact': None, 'affl': None}
# {'first_name': ' Biao', 'last_name': 'Xu', 'contact': None, 'affl': None}
# {'first_name': ' Jun', 'last_name': 'Yang', 'contact': None, 'affl': None}
# {'first_name': ' Weirong', 'last_name': 'Yan', 'contact': None, 'affl': None}
# {'first_name': ' Vinod K.', 'last_name': 'Diwan', 'contact': None, 'affl': None}
# {'first_name': ' Rainer', 'last_name': 'Sauerborn', 'contact': None, 'affl': None}
# {'first_name': ' Hengjin', 'last_name': 'Dong', 'contact': None, 'affl': None}
# {'first_name': ' Bevan', 'last_name': 'Koopman', 'contact': None, 'affl': None}
# {'first_name': ' Sarvnaz', 'last_name': 'Karimi', 'contact': None, 'affl': None}
# {'first_name': ' Anthony', 'last_name': 'Nguyen', 'contact': None, 'affl': None}
# {'first_name': ' Rhydwyn', 'last_name': 'McGuire', 'contact': None, 'affl': None}
# {'first_name': ' David', 'last_name': 'Muscatello', 'contact': None, 'affl': None}
# {'first_name': ' Madonna', 'last_name': 'Kemp', 'contact': None, 'affl': None}
# {'first_name': ' Donna', 'last_name': 'Truran', 'contact': None, 'affl': None}
# {'first_name': ' Ming', 'last_name': 'Zhang', 'contact': None, 'affl': None}
# {'first_name': ' Sarah', 'last_name': 'Thackway', 'contact': None, 'affl': None}
# {'first_name': ' Magnus', 'last_name': 'Boman', 'contact': None, 'affl': None}
# {'first_name': ' Pedro', 'last_name': 'Sanches', 'contact': None, 'affl': None}
# {'first_name': ' Lydia N', 'last_name': 'Drumright', 'contact': None, 'affl': None}
# {'first_name': ' Simon DW', 'last_name': 'Frost', 'contact': None, 'affl': None}
# {'first_name': ' Alex J', 'last_name': 'Elliot', 'contact': None, 'affl': None}
# {'first_name': ' Mike', 'last_name': 'Catchpole', 'contact': None, 'affl': None}
# {'first_name': ' Richard G', 'last_name': 'Pebody', 'contact': None, 'affl': None}
# {'first_name': ' Mark', 'last_name': 'Atkins', 'contact': None, 'affl': None}
# {'first_name': ' John', 'last_name': 'Harrison', 'contact': None, 'affl': None}
# {'first_name': ' Penny', 'last_name': 'Parker', 'contact': None, 'affl': None}
# {'first_name': ' Alison H', 'last_name': 'Holmes', 'contact': None, 'affl': None}
# {'first_name': ' Abu James', 'last_name': 'Sundufu', 'contact': None, 'affl': None}
# {'first_name': ' Rashid', 'last_name': 'Ansumana', 'contact': None, 'affl': None}
# {'first_name': ' Alfred Swarray', 'last_name': 'Bockarie', 'contact': None, 'affl': None}
# {'first_name': ' Umaru', 'last_name': 'Bangura', 'contact': None, 'affl': None}
# {'first_name': ' Joseph Morrison', 'last_name': 'Lamin', 'contact': None, 'affl': None}
# {'first_name': ' Kathryn H.', 'last_name': 'Jacobsen', 'contact': None, 'affl': None}
# {'first_name': ' David Andrew', 'last_name': 'Stenger', 'contact': None, 'affl': None}
# {'first_name': ' D.', 'last_name': 'Thiam', 'contact': None, 'affl': None}
# {'first_name': ' M.', 'last_name': 'Niang', 'contact': None, 'affl': None}
# {'first_name': ' N.', 'last_name': 'Dia', 'contact': None, 'affl': None}
# {'first_name': ' F. D.', 'last_name': 'Sarr', 'contact': None, 'affl': None}
# {'first_name': ' D.', 'last_name': 'Goudiab', 'contact': None, 'affl': None}
# {'first_name': ' M.-L.', 'last_name': 'Senghor', 'contact': None, 'affl': None}
# {'first_name': ' D.', 'last_name': 'Kiori', 'contact': None, 'affl': None}
# {'first_name': ' T.', 'last_name': 'Faye', 'contact': None, 'affl': None}
# {'first_name': ' E.', 'last_name': 'Espié', 'contact': None, 'affl': None}
# {'first_name': ' I. O.', 'last_name': 'Ba', 'contact': None, 'affl': None}
# {'first_name': ' V.', 'last_name': 'Richard', 'contact': None, 'affl': None}
# {'first_name': ' Jian', 'last_name': 'Zou', 'contact': None, 'affl': None}
# {'first_name': ' Alan F', 'last_name': 'Karr', 'contact': None, 'affl': None}
# {'first_name': ' Gauri', 'last_name': 'Datta', 'contact': None, 'affl': None}
# {'first_name': ' James', 'last_name': 'Lynch', 'contact': None, 'affl': None}
# {'first_name': ' Shaun', 'last_name': 'Grannis', 'contact': None, 'affl': None}
# {'first_name': ' Mathilde', 'last_name': 'Pivette', 'contact': None, 'affl': None}
# {'first_name': ' Judith E', 'last_name': 'Mueller', 'contact': None, 'affl': None}
# {'first_name': ' Pascal', 'last_name': 'Crépey', 'contact': None, 'affl': None}
# {'first_name': ' Avner', 'last_name': 'Bar-Hen', 'contact': None, 'affl': None}
# {'first_name': ' Nicole', 'last_name': 'Rosenkötter', 'contact': None, 'affl': None}
# {'first_name': ' Alexandra', 'last_name': 'Ziemann', 'contact': None, 'affl': None}
# {'first_name': ' Thomas', 'last_name': 'Krafft', 'contact': None, 'affl': None}
# {'first_name': ' Luis Garcia-Castrillo', 'last_name': 'Riesgo', 'contact': None, 'affl': None}
# {'first_name': ' Gernot', 'last_name': 'Vergeiner', 'contact': None, 'affl': None}
# {'first_name': ' Helmut', 'last_name': 'Brand', 'contact': None, 'affl': None}
# {'first_name': ' Solweig', 'last_name': 'Gerbier-Colomban', 'contact': None, 'affl': None}
# {'first_name': ' Véronique', 'last_name': 'Potinet-Pagliaroli', 'contact': None, 'affl': None}
# {'first_name': ' Marie-Hélène', 'last_name': 'Metzger', 'contact': None, 'affl': None}
# {'first_name': ' Flavie', 'last_name': 'Vial', 'contact': None, 'affl': None}
# {'first_name': ' Martin', 'last_name': 'Reist', 'contact': None, 'affl': None}
# {'first_name': ' Gillian D', 'last_name': 'Alton', 'contact': None, 'affl': None}
# {'first_name': ' David L', 'last_name': 'Pearl', 'contact': None, 'affl': None}
# {'first_name': ' Ken G', 'last_name': 'Bateman', 'contact': None, 'affl': None}
# {'first_name': ' Bruce', 'last_name': 'McNab', 'contact': None, 'affl': None}
# {'first_name': ' Olaf', 'last_name': 'Berke', 'contact': None, 'affl': None}
# {'first_name': ' Brian', 'last_name': 'Thelen', 'contact': None, 'affl': None}
# {'first_name': ' Nancy HF', 'last_name': 'French', 'contact': None, 'affl': None}
# {'first_name': ' Benjamin W', 'last_name': 'Koziol', 'contact': None, 'affl': None}
# {'first_name': ' Michael', 'last_name': 'Billmire', 'contact': None, 'affl': None}
# {'first_name': ' Robert Chris', 'last_name': 'Owen', 'contact': None, 'affl': None}
# {'first_name': ' Jeffrey', 'last_name': 'Johnson', 'contact': None, 'affl': None}
# {'first_name': ' Michele', 'last_name': 'Ginsberg', 'contact': None, 'affl': None}
# {'first_name': ' Tatiana', 'last_name': 'Loboda', 'contact': None, 'affl': None}
# {'first_name': ' Shiliang', 'last_name': 'Wu', 'contact': None, 'affl': None}
# {'first_name': ' Nicole', 'last_name': 'Rosenkötter', 'contact': None, 'affl': None}
# {'first_name': ' Alexandra', 'last_name': 'Ziemann', 'contact': None, 'affl': None}
# {'first_name': ' Luis Garcia-Castrillo', 'last_name': 'Riesgo', 'contact': None, 'affl': None}
# {'first_name': ' Jean Bernard', 'last_name': 'Gillet', 'contact': None, 'affl': None}
# {'first_name': ' Gernot', 'last_name': 'Vergeiner', 'contact': None, 'affl': None}
# {'first_name': ' Thomas', 'last_name': 'Krafft', 'contact': None, 'affl': None}
# {'first_name': ' Helmut', 'last_name': 'Brand', 'contact': None, 'affl': None}
# {'first_name': ' Solweig', 'last_name': 'Gerbier-Colomban', 'contact': None, 'affl': None}
# {'first_name': ' Quentin', 'last_name': 'Gicquel', 'contact': None, 'affl': None}
# {'first_name': ' Anne-Laure', 'last_name': 'Millet', 'contact': None, 'affl': None}
# {'first_name': ' Christophe', 'last_name': 'Riou', 'contact': None, 'affl': None}
# {'first_name': ' Jacqueline', 'last_name': 'Grando', 'contact': None, 'affl': None}
# {'first_name': ' Stefan', 'last_name': 'Darmoni', 'contact': None, 'affl': None}
# {'first_name': ' Véronique', 'last_name': 'Potinet-Pagliaroli', 'contact': None, 'affl': None}
# {'first_name': ' Marie-Hélène', 'last_name': 'Metzger', 'contact': None, 'affl': None}
# {'first_name': ' Céline', 'last_name': 'Dupuy', 'contact': None, 'affl': None}
# {'first_name': ' Eric', 'last_name': 'Morignat', 'contact': None, 'affl': None}
# {'first_name': ' Xavier', 'last_name': 'Maugey', 'contact': None, 'affl': None}
# {'first_name': ' Jean-Luc', 'last_name': 'Vinard', 'contact': None, 'affl': None}
# {'first_name': ' Pascal', 'last_name': 'Hendrikx', 'contact': None, 'affl': None}
# {'first_name': ' Christian', 'last_name': 'Ducrot', 'contact': None, 'affl': None}
# {'first_name': ' Didier', 'last_name': 'Calavas', 'contact': None, 'affl': None}
# {'first_name': ' Emilie', 'last_name': 'Gay', 'contact': None, 'affl': None}
# {'first_name': ' Aaron W', 'last_name': 'Cashmore', 'contact': None, 'affl': None}
# {'first_name': ' David J', 'last_name': 'Muscatello', 'contact': None, 'affl': None}
# {'first_name': ' Alistair', 'last_name': 'Merrifield', 'contact': None, 'affl': None}
# {'first_name': ' Paula', 'last_name': 'Spokes', 'contact': None, 'affl': None}
# {'first_name': ' Kristine', 'last_name': 'Macartney', 'contact': None, 'affl': None}
# {'first_name': ' Bin B', 'last_name': 'Jalaludin', 'contact': None, 'affl': None}
# {'first_name': ' Anna', 'last_name': 'Chu', 'contact': None, 'affl': None}
# {'first_name': ' Rachel', 'last_name': 'Savage', 'contact': None, 'affl': None}
# {'first_name': ' Don', 'last_name': 'Willison', 'contact': None, 'affl': None}
# {'first_name': ' Natasha S', 'last_name': 'Crowcroft', 'contact': None, 'affl': None}
# {'first_name': ' Laura C', 'last_name': 'Rosella', 'contact': None, 'affl': None}
# {'first_name': ' Doug', 'last_name': 'Sider', 'contact': None, 'affl': None}
# {'first_name': ' Jason', 'last_name': 'Garay', 'contact': None, 'affl': None}
# {'first_name': ' Ian', 'last_name': 'Gemmill', 'contact': None, 'affl': None}
# {'first_name': ' Anne-Luise', 'last_name': 'Winter', 'contact': None, 'affl': None}
# {'first_name': ' Richard F', 'last_name': 'Davies', 'contact': None, 'affl': None}
# {'first_name': ' Ian', 'last_name': 'Johnson', 'contact': None, 'affl': None}
# {'first_name': ' Terri L', 'last_name': 'O’Sullivan', 'contact': None, 'affl': None}
# {'first_name': ' Robert M', 'last_name': 'Friendship', 'contact': None, 'affl': None}
# {'first_name': ' David L', 'last_name': 'Pearl', 'contact': None, 'affl': None}
# {'first_name': ' Beverly', 'last_name': 'McEwen', 'contact': None, 'affl': None}
# {'first_name': ' Catherine E', 'last_name': 'Dewey', 'contact': None, 'affl': None}
# {'first_name': ' Wei-rong', 'last_name': 'Yan', 'contact': None, 'affl': None}
# {'first_name': ' Shao-fa', 'last_name': 'Nie', 'contact': None, 'affl': None}
# {'first_name': ' Biao', 'last_name': 'Xu', 'contact': None, 'affl': None}
# {'first_name': ' Heng-jin', 'last_name': 'Dong', 'contact': None, 'affl': None}
# {'first_name': ' Lars', 'last_name': 'Palm', 'contact': None, 'affl': None}
# {'first_name': ' Vinod K', 'last_name': 'Diwan', 'contact': None, 'affl': None}
# {'first_name': ' Andrea', 'last_name': 'Schaffer', 'contact': None, 'affl': None}
# {'first_name': ' David', 'last_name': 'Muscatello', 'contact': None, 'affl': None}
# {'first_name': ' Richard', 'last_name': 'Broome', 'contact': None, 'affl': None}
# {'first_name': ' Stephen', 'last_name': 'Corbett', 'contact': None, 'affl': None}
# {'first_name': ' Wayne', 'last_name': 'Smith', 'contact': None, 'affl': None}
# {'first_name': ' C', 'last_name': 'King', 'contact': None, 'affl': None}
# {'first_name': ' L', 'last_name': 'Garcia Alvarez', 'contact': None, 'affl': None}
# {'first_name': ' A', 'last_name': 'Holmes', 'contact': None, 'affl': None}
# {'first_name': ' P', 'last_name': 'Aylin', 'contact': None, 'affl': None}
# {'first_name': ' Blaine', 'last_name': 'Reeder', 'contact': None, 'affl': None}
# {'first_name': ' Debra', 'last_name': 'Revere', 'contact': None, 'affl': None}
# {'first_name': ' Donald R', 'last_name': 'Olson', 'contact': None, 'affl': None}
# {'first_name': ' William B', 'last_name': 'Lober', 'contact': None, 'affl': None}
# {'first_name': ' Eva', 'last_name': 'Warns-Petit', 'contact': None, 'affl': None}
# {'first_name': ' Eric', 'last_name': 'Morignat', 'contact': None, 'affl': None}
# {'first_name': ' Marc', 'last_name': 'Artois', 'contact': None, 'affl': None}
# {'first_name': ' Didier', 'last_name': 'Calavas', 'contact': None, 'affl': None}
# {'first_name': ' Shui Shan', 'last_name': 'Lee', 'contact': None, 'affl': None}
# {'first_name': ' Ngai Sze', 'last_name': 'Wong', 'contact': None, 'affl': None}
# {'first_name': ' J.', 'last_name': 'Korte', 'contact': None, 'affl': None}
# {'first_name': ' C.', 'last_name': 'Läubrich', 'contact': None, 'affl': None}
# {'first_name': ' H.', 'last_name': 'Fickenscher', 'contact': None, 'affl': None}
# {'first_name': ' P.', 'last_name': 'Rautenberg', 'contact': None, 'affl': None}
# {'first_name': ' Gillian D', 'last_name': 'Alton', 'contact': None, 'affl': None}
# {'first_name': ' David L', 'last_name': 'Pearl', 'contact': None, 'affl': None}
# {'first_name': ' Ken G', 'last_name': 'Bateman', 'contact': None, 'affl': None}
# {'first_name': ' W Bruce', 'last_name': 'McNab', 'contact': None, 'affl': None}
# {'first_name': ' Olaf', 'last_name': 'Berke', 'contact': None, 'affl': None}
# {'first_name': ' Colin', 'last_name': 'Robertson', 'contact': None, 'affl': None}
# {'first_name': ' Trisalyn A', 'last_name': 'Nelson', 'contact': None, 'affl': None}
# {'first_name': ' David J', 'last_name': 'Savory', 'contact': None, 'affl': None}
# {'first_name': ' Kenneth L', 'last_name': 'Cox', 'contact': None, 'affl': None}
# {'first_name': ' Michael', 'last_name': 'Emch', 'contact': None, 'affl': None}
# {'first_name': ' Farrokh', 'last_name': 'Alemi', 'contact': None, 'affl': None}
# {'first_name': ' David C', 'last_name': 'Pattie', 'contact': None, 'affl': None}
# {'first_name': ' Leslie P.', 'last_name': 'Francis', 'contact': None, 'affl': None}
# {'first_name': ' Margaret P.', 'last_name': 'Battin', 'contact': None, 'affl': None}
# {'first_name': ' Jay', 'last_name': 'Jacobson', 'contact': None, 'affl': None}
# {'first_name': ' Charles', 'last_name': 'Smith', 'contact': None, 'affl': None}
# {'first_name': ' Farzad', 'last_name': 'Mostashari', 'contact': None, 'affl': None}
# {'first_name': ' Annie', 'last_name': 'Fine', 'contact': None, 'affl': None}
# {'first_name': ' Debjani', 'last_name': 'Das', 'contact': None, 'affl': None}
# {'first_name': ' John', 'last_name': 'Adams', 'contact': None, 'affl': None}
# {'first_name': ' Marcelle', 'last_name': 'Layton', 'contact': None, 'affl': None}
# {'first_name': ' Weng-Keen', 'last_name': 'Wong', 'contact': None, 'affl': None}
# {'first_name': ' Andrew', 'last_name': 'Moore', 'contact': None, 'affl': None}
# {'first_name': ' Gregory', 'last_name': 'Cooper', 'contact': None, 'affl': None}
# {'first_name': ' Michael', 'last_name': 'Wagner', 'contact': None, 'affl': None}
# {'first_name': ' Julie A.', 'last_name': 'Pavlin', 'contact': None, 'affl': None}
# {'first_name': ' Daniel M.', 'last_name': 'Sosin', 'contact': None, 'affl': None}

# %%
from datetime import datetime
values_list = []
for index, row in parse_df.iterrows():
#     unique_id = row['uniqueid']
    unique_id = None
    title = row['title']
    journal_name = row['journalName']
    journal_iso = row['journalISO']
    pub_type = row['pubtype']
    publication_date = row['publishdatefull']
    date_format = datetime.strptime(publication_date, '%Y-%m-%d')
    try:
        pub_day = date_format.day
    except:
        pub_day = None
    try:
        pub_month = date_format.month
    except:
        pub_month = None
    try:
        pub_year = date_format.year
    except:
        pub_year = None

    values_list.append((unique_id,title,journal_name,journal_iso,pub_type,publication_date,pub_day,pub_month,pub_year))

# %%
values_list
# Out:
# [(None,
#   'Clinical assessment is a neglected component of outbreak preparedness: evidence from refugee camps in Greece',
#   'BMC Medicine',
#   '12916',
#   'OriginalPaper',
#   '2018-03-19',
#   19,
#   3,
#   2018),
#  (None,
#   'Syndromic surveillance for West Nile virus using raptors in rehabilitation',
#   'BMC Veterinary Research',
#   '12917',
#   'OriginalPaper',
#   '2017-11-29',
#   29,
#   11,
#   2017),
#  (None,
#   'Correcting for day of the week and public holiday effects: improving a national daily syndromic surveillance service for detecting public health threats',
#   'BMC Public Health',
#   '12889',
#   'OriginalPaper',
#   '2017-05-19',
#   19,
#   5,
#   2017),
#  (None,
#   'Early outbreak detection by linking health advice line calls to water distribution areas retrospectively demonstrated in a large waterborne outbreak of cryptosporidiosis in Sweden',
#   'BMC Public Health',
#   '12889',
#   'OriginalPaper',
#   '2017-04-18',
#   18,
#   4,
#   2017),
#  (None,
#   'Methodological challenges to multivariate syndromic surveillance: a case study using Swiss animal health data',
#   'BMC Veterinary Research',
#   '12917',
#   'OriginalPaper',
#   '2016-12-20',
#   20,
#   12,
#   2016),
#  (None,
#   'SCM: a practical tool to implement hospital-based syndromic surveillance',
#   'BMC Research Notes',
#   '13104',
#   'OriginalPaper',
#   '2016-06-18',
#   18,
#   6,
#   2016),
#  (None,
#   'Combining syndromic surveillance and ILI data using particle filter for epidemic state estimation',
#   'Flexible Services and Manufacturing Journal',
#   '10696',
#   'OriginalPaper',
#   '2016-06-01',
#   1,
#   6,
#   2016),
#  (None,
#   'Use of big data in the surveillance of veterinary diseases: early detection of tick paralysis in companion animals',
#   'Parasites & Vectors',
#   '13071',
#   'OriginalPaper',
#   '2016-05-23',
#   23,
#   5,
#   2016),
#  (None,
#   'Syndromic surveillance of Flu on Twitter using weakly supervised temporal topic models',
#   'Data Mining and Knowledge Discovery',
#   '10618',
#   'OriginalPaper',
#   '2016-05-01',
#   1,
#   5,
#   2016),
#  (None,
#   'Human temperatures for syndromic surveillance in the emergency department: data from the autumn wave of the 2009 swine flu (H1N1) pandemic and a seasonal influenza outbreak',
#   'BMC Emergency Medicine',
#   '12873',
#   'OriginalPaper',
#   '2016-03-09',
#   9,
#   3,
#   2016),
#  (None,
#   'The usefulness of school-based syndromic surveillance for detecting malaria epidemics: experiences from a pilot project in Ethiopia',
#   'BMC Public Health',
#   '12889',
#   'OriginalPaper',
#   '2016-01-09',
#   9,
#   1,
#   2016),
#  (None,
#   'Citizen Science and Wildlife Disease Surveillance',
#   'EcoHealth',
#   '10393',
#   'ReviewPaper',
#   '2015-12-01',
#   1,
#   12,
#   2015),
#  (None,
#   'A cost-effectiveness analysis of three components of a syndromic surveillance system for the early warning of epidemics in rural China',
#   'BMC Public Health',
#   '12889',
#   'OriginalPaper',
#   '2015-11-14',
#   14,
#   11,
#   2015),
#  (None,
#   'Measuring costs of data collection at village clinics by village doctors for a syndromic surveillance system-a cross sectional survey from China',
#   'BMC Health Services Research',
#   '12913',
#   'OriginalPaper',
#   '2015-07-25',
#   25,
#   7,
#   2015),
#  (None,
#   'Automatic classification of diseases from free-text death certificates for real-time surveillance',
#   'BMC Medical Informatics and Decision Making',
#   '12911',
#   'OriginalPaper',
#   '2015-07-15',
#   15,
#   7,
#   2015),
#  (None,
#   'Sensemaking in Intelligent Health Data Analytics',
#   'KI - Künstliche Intelligenz',
#   '13218',
#   'OriginalPaper',
#   '2015-06-01',
#   1,
#   6,
#   2015),
#  (None,
#   'Assessing the use of hospital staff influenza-like absence (ILA) for enhancing hospital preparedness and national surveillance',
#   'BMC Infectious Diseases',
#   '12879',
#   'OriginalPaper',
#   '2015-03-01',
#   1,
#   3,
#   2015),
#  (None,
#   'Syndromic surveillance of peste des petits ruminants and other animal diseases in Koinadugu district, Sierra Leone, 2011–2012',
#   'Tropical Animal Health and Production',
#   '11250',
#   'BriefCommunication',
#   '2015-02-01',
#   1,
#   2,
#   2015),
#  (None,
#   'Renforcement du réseau de surveillance sentinelle de la grippe au Sénégal et résultats',
#   'Bulletin de la Société de pathologie exotique',
#   '13149',
#   'OriginalPaper',
#   '2015-02-01',
#   1,
#   2,
#   2015),
#  (None,
#   'A Bayesian spatio–temporal approach for real–time detection of disease outbreaks: a case study',
#   'BMC Medical Informatics and Decision Making',
#   '12911',
#   'OriginalPaper',
#   '2014-12-05',
#   5,
#   12,
#   2014),
#  (None,
#   'Drug sales data analysis for outbreak detection of infectious diseases: a systematic literature review',
#   'BMC Infectious Diseases',
#   '12879',
#   'OriginalPaper',
#   '2014-11-18',
#   18,
#   11,
#   2014),
#  (None,
#   'Non-infectious events under the International Health Regulations (2005) in Europe – a case for syndromic surveillance',
#   'Journal of Public Health Policy',
#   '41271',
#   'OriginalPaper',
#   '2014-08-01',
#   1,
#   8,
#   2014),
#  (None,
#   'Can epidemic detection systems at the hospital level complement regional surveillance networks: Case study with the influenza epidemic?',
#   'BMC Infectious Diseases',
#   '12879',
#   'OriginalPaper',
#   '2014-07-10',
#   10,
#   7,
#   2014),
#  (None,
#   'Evaluation of Swiss slaughterhouse data for integration in a syndromic surveillance system',
#   'BMC Veterinary Research',
#   '12917',
#   'OriginalPaper',
#   '2014-01-31',
#   31,
#   1,
#   2014),
#  (None,
#   'Comparison of covariate adjustment methods using space-time scan statistics for food animal syndromic surveillance',
#   'BMC Veterinary Research',
#   '12917',
#   'OriginalPaper',
#   '2013-11-18',
#   18,
#   11,
#   2013),
#  (None,
#   'Modeling acute respiratory illness during the 2007 San Diego wildland fires using a coupled emissions-transport system and generalized additive modeling',
#   'Environmental Health',
#   '12940',
#   'OriginalPaper',
#   '2013-11-05',
#   5,
#   11,
#   2013),
#  (None,
#   'Validity and timeliness of syndromic influenza surveillance during the autumn/winter wave of A (H1N1) influenza 2009: results of emergency medical dispatch, ambulance and emergency department data from three European regions',
#   'BMC Public Health',
#   '12889',
#   'OriginalPaper',
#   '2013-10-01',
#   1,
#   10,
#   2013),
#  (None,
#   'Evaluation of syndromic algorithms for detecting patients with potentially transmissible infectious diseases based on computerised emergency-department data',
#   'BMC Medical Informatics and Decision Making',
#   '12911',
#   'OriginalPaper',
#   '2013-09-03',
#   3,
#   9,
#   2013),
#  (None,
#   'Defining syndromes using cattle meat inspection data for syndromic surveillance purposes: a statistical approach with the 2005–2010 data from ten French slaughterhouses',
#   'BMC Veterinary Research',
#   '12917',
#   'OriginalPaper',
#   '2013-04-30',
#   30,
#   4,
#   2013),
#  (None,
#   'Relationship between the population incidence of pertussis in children in New South Wales, Australia and emergency department visits with cough: a time series analysis',
#   'BMC Medical Informatics and Decision Making',
#   '12911',
#   'OriginalPaper',
#   '2013-03-28',
#   28,
#   3,
#   2013),
#  (None,
#   'The use of syndromic surveillance for decision-making during the H1N1 pandemic: A qualitative study',
#   'BMC Public Health',
#   '12889',
#   'OriginalPaper',
#   '2012-10-30',
#   30,
#   10,
#   2012),
#  (None,
#   'Identifying an outbreak of a novel swine disease using test requests for porcine reproductive and respiratory syndrome as a syndromic surveillance tool',
#   'BMC Veterinary Research',
#   '12917',
#   'OriginalPaper',
#   '2012-10-16',
#   16,
#   10,
#   2012),
#  (None,
#   'Establishing a web-based integrated surveillance system for early detection of infectious disease epidemic in rural China: a field experimental study',
#   'BMC Medical Informatics and Decision Making',
#   '12911',
#   'OriginalPaper',
#   '2012-02-03',
#   3,
#   2,
#   2012),
#  (None,
#   'Emergency department visits, ambulance calls, and mortality associated with an exceptional heat wave in Sydney, Australia, 2011: a time-series analysis',
#   'Environmental Health',
#   '12940',
#   'OriginalPaper',
#   '2012-01-24',
#   24,
#   1,
#   2012),
#  (None,
#   'Developing proxy indicators of healthcare associated infections to support syndromic surveillance in a UK academic health science centre',
#   'BMC Proceedings',
#   '12919',
#   'Abstract',
#   '2011-06-29',
#   29,
#   6,
#   2011),
#  (None,
#   'Perceived usefulness of a distributed community-based syndromic surveillance system: a pilot qualitative evaluation study',
#   'BMC Research Notes',
#   '13104',
#   'Report',
#   '2011-06-14',
#   14,
#   6,
#   2011),
#  (None,
#   'Unsupervised clustering of wildlife necropsy data for syndromic surveillance',
#   'BMC Veterinary Research',
#   '12917',
#   'OriginalPaper',
#   '2010-12-16',
#   16,
#   12,
#   2010),
#  (None,
#   'Reconstruction of epidemic curves for pandemic influenza A (H1N1) 2009 at city and sub-city levels',
#   'Virology Journal',
#   '12985',
#   'Report',
#   '2010-11-16',
#   16,
#   11,
#   2010),
#  (None,
#   'Validierung einer syndromischen Surveillance akuter Respirationstrakt-Erkrankungen in Kindergärten und Kindertagesstätten Schleswig-Holsteins (SHARE)',
#   'Bundesgesundheitsblatt - Gesundheitsforschung - Gesundheitsschutz',
#   '103',
#   'OriginalPaper',
#   '2010-09-01',
#   1,
#   9,
#   2010),
#  (None,
#   'Factors associated with whole carcass condemnation rates in provincially-inspected abattoirs in Ontario 2001-2007: implications for food animal syndromic surveillance',
#   'BMC Veterinary Research',
#   '12917',
#   'OriginalPaper',
#   '2010-08-12',
#   12,
#   8,
#   2010),
#  (None,
#   'Review of software for space-time disease surveillance',
#   'International Journal of Health Geographics',
#   '12942',
#   'ReviewPaper',
#   '2010-03-12',
#   12,
#   3,
#   2010),
#  (None,
#   'Enhancing spatial detection accuracy for syndromic surveillance with street level incidence data',
#   'International Journal of Health Geographics',
#   '12942',
#   'OriginalPaper',
#   '2010-01-18',
#   18,
#   1,
#   2010),
#  (None,
#   'Syndromic Surveillance and Patients as Victims and Vectors',
#   'Journal of Bioethical Inquiry',
#   '11673',
#   'OriginalPaper',
#   '2009-06-01',
#   1,
#   6,
#   2009),
#  (None,
#   'Use of ambulance dispatch data as an early warning system for communitywide influenzalike illness, New York City',
#   'Journal of Urban Health',
#   '11524',
#   'OriginalPaper',
#   '2003-03-01',
#   1,
#   3,
#   2003),
#  (None,
#   'Wsare: What’s strange about recent events?',
#   'Journal of Urban Health',
#   '11524',
#   'OriginalPaper',
#   '2003-03-01',
#   1,
#   3,
#   2003),
#  (None,
#   'Investigation of disease outbreaks detected by “syndromic” surveillance systems',
#   'Journal of Urban Health',
#   '11524',
#   'OriginalPaper',
#   '2003-03-01',
#   1,
#   3,
#   2003),
#  (None,
#   'Draft framework for evaluating syndromic surveillance systems',
#   'Journal of Urban Health',
#   '11524',
#   'OriginalPaper',
#   '2003-03-01',
#   1,
#   3,
#   2003)]

# %%
parse_df.shape
# Out:
# (47, 13)

# %%
import NCBIPush
importlib.reload(NCBIPush)
# Out:
# <module 'NCBIPush' from '/Users/sophierand/Desktop/Github/lit_rev_tool/NCBIPush.py'>

# %%
con,cur = helper.connect_to_db()
# Out:
# Connecting to database
# host='localhost' dbname= 'lit_rev' user='postgres' password='gres'

# %%
parse_df = helper.id_run('parse','springer')

# %%
cur_id,cur_id_tup = NCBIPush.push_id(cur,con,input_term,parse_df)

# %%
# cur_id,cur_id_tup = NCBIPush.push_id(cur,con,input_term,parse_df)
new_data = NCBIPush.push_detail(cur,con,parse_df,cur_id,cur_id_tup)
NCBIPush.push_unique_id(cur,con,new_data)
full_df = NCBIPush.merge_ids(cur,con,new_data)
NCBIPush.push_title(cur,con,full_df)
NCBIPush.push_author(cur,con,full_df)
NCBIPush.push_keyword(cur,con,full_df)
NCBIPush.push_text(cur,con,full_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-8d24b315fe60> in <module>()
#       4 full_df = NCBIPush.merge_ids(cur,con,new_data)
#       5 NCBIPush.push_title(cur,con,full_df)
# ----> 6 NCBIPush.push_author(cur,con,full_df)
#       7 NCBIPush.push_keyword(cur,con,full_df)
#       8 NCBIPush.push_text(cur,con,full_df)
#
# ~/Desktop/Github/lit_rev_tool/NCBIPush.py in push_author(cur, con, full_data_df)
#     138                 auth_count += 1
#     139                 if auth_count < 4:
# --> 140                     values_list.append((unique_id, auth['fname'], auth['lname'], contributor_type,contributor_contact,auth['affl']))
#     141                 else:
#     142                     break
#
# KeyError: 'fname'

# %%
new_data = NCBIPush.push_detail(cur,con,parse_df,cur_id,cur_id_tup)

# %%
json_path = "unique_identifiers.json"
json_file = json.load(open(json_path,"r"))
json_file
# Out:
# [{'id': 'jtvnh69DTi6W13zHnxpN610x6',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance',
#   'record_count': '8932',
#   'run_date': '2018-04-17 10:58'},
#  {'id': 'R6gCZTvkKyzUXCoojcwMxYD7w',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-17 10:58'},
#  {'id': 'o5R3kmYuymYdx6U6R31QA19Ri',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-17 10:58'},
#  {'id': 'dMrTi2Msbzidv9yd6McYKuTIL',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance',
#   'record_count': '8932',
#   'run_date': '2018-04-17 11:01'},
#  {'id': 'GPaBAeSWGUYSyfxIaZXPmLduN',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-17 11:01'},
#  {'id': 'hJvDlxsB3M6TW1IFfioOnWUnQ',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-17 11:02'},
#  {'id': 'NS9Cae8OuVBXpTbztMTCpijf0',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance',
#   'record_count': '8932',
#   'run_date': '2018-04-17 11:02'},
#  {'id': 'VK5Mey8fy2rgFxjeqwaoMg06i',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-17 11:02'},
#  {'id': 'L2DTA3FvQ1iEqTobvBUy9ypdT',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-17 11:02'},
#  {'id': 'CvLba4P8cpsFTtKBeIhv1B6gW',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance AND emergency room',
#   'record_count': '266',
#   'run_date': '2018-04-17 11:48'},
#  {'id': 'LIHUgub2kh7ziyPL65zXQRmyS',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-17 11:48'},
#  {'id': 'qMXfpfYaVIFhjxUhdw8gTxY0I',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-17 11:48'},
#  {'id': 'Ex3t2Jn8IXDRmUEWNAWieNz2l',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance AND emergency room',
#   'record_count': '266',
#   'run_date': '2018-04-17 12:42'},
#  {'id': 'pdiR8MJQQT0cLnjZnYyME0NV6',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-17 12:42'},
#  {'id': 'TXqg2NkR5YYAMHsLK3LJU5ZBu',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-17 12:42'},
#  {'id': 'RWYR9GhGorXHwhO8Ukd9jUu3E',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance',
#   'record_count': '8936',
#   'run_date': '2018-04-18 08:22'},
#  {'id': 'cmtuAOeEjFM6uOih14OFnkMw1',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 08:23'},
#  {'id': 'l2M8k3YkMmf8so0IQgsbf2eC7',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 08:23'},
#  {'id': 'tdJVMvBFYhqabt9fcrlpePMU4',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance',
#   'record_count': '8936',
#   'run_date': '2018-04-18 08:43'},
#  {'id': 'xcqWmEqQJonRh8w2XDbkD2T1y',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 08:43'},
#  {'id': 'UHWzCLZ2FRGRFU6WX56j76BTe',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 08:43'},
#  {'id': '7NDJicmI6OhwJovmOJw0odVmH',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance',
#   'record_count': '8936',
#   'run_date': '2018-04-18 08:53'},
#  {'id': 'F89jvDJvbggJQc0QypIP1WEVd',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 08:53'},
#  {'id': 'R5yFmaQG3xLomR6lGlkzj5SQR',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 08:53'},
#  {'id': 'ijQeZfZgSOFoJrH6wngHpbG5e',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance',
#   'record_count': '8936',
#   'run_date': '2018-04-18 09:14'},
#  {'id': 'A5eVnkvzyvDQm7d2COkiRL6xj',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 09:15'},
#  {'id': 'EwaoHLNlOXu9POPxazT2cQ9d7',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 09:15'},
#  {'id': 'fcCuFmkNY97pLvrR6FvK6wW0G',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance AND emergency department',
#   'record_count': '417',
#   'run_date': '2018-04-18 11:18'},
#  {'id': 'XvJC4slLHhIlzAVSRRa2KZHF8',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 11:19'},
#  {'id': '8hdh4gU3Xi0gpkOKPkeLaAamN',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 11:19'},
#  {'id': 'KAVMhHjq8Nh7BUstbFm1dfTHT',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance AND emergency room',
#   'record_count': '266',
#   'run_date': '2018-04-18 11:40'},
#  {'id': 'x1PylWCd7z3quSiCTnFq26koU',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 11:40'},
#  {'id': 'yDydDNHVYIdKR0BTbUy60OSL4',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 11:40'},
#  {'id': 'yD7juPXmKcYEjQns8VXZcoIRP',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance',
#   'record_count': '8936',
#   'run_date': '2018-04-18 11:43'},
#  {'id': 'CdncyN1crfdd7TPHqz5j1oQWk',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 11:43'},
#  {'id': 'yyqVPJF9q64GfFUnauASdM5Jh',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 11:43'},
#  {'id': 'KYXmmm93uFCssa4TxiUTX4J5c',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance',
#   'record_count': '8936',
#   'run_date': '2018-04-18 11:52'},
#  {'id': 'saMuIMKvtlCWM9ZVqm7RcNcYU',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 11:52'},
#  {'id': 'QdXFsa2rcmTsRmBeRZHyQR3aj',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 11:52'},
#  {'id': 'bCKAEaLWmhUjcDAqVVZNlDEgK',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance AND emergency department',
#   'record_count': 417,
#   'run_date': '2018-04-18 12:16'},
#  {'id': 'tnhfYBw0kKaPT4y3ZbVu70L2H',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 417,
#   'run_date': '2018-04-18 12:16'},
#  {'id': 'b65NiVNfBHdIkMHAakXGl8oy7',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 417,
#   'run_date': '2018-04-18 12:17'},
#  {'id': '6V29uqItwa6oaJsbKdMN6i26Q',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance AND emergency room',
#   'record_count': 266,
#   'run_date': '2018-04-18 12:19'},
#  {'id': 'y2IJGJvWofcjTbxg0PdrorKLM',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance AND emergency room',
#   'record_count': 266,
#   'run_date': '2018-04-18 12:33'},
#  {'id': 'bzwPRBCcyFVfR4xGNCfzAeDMX',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance AND emergency room',
#   'record_count': 266,
#   'run_date': '2018-04-18 12:38'},
#  {'id': 'qqYE5UOOQrkP2AQ12MuplPNps',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 12:39'},
#  {'id': 'NfXFTb2wBLNcNDo7qxckthqYx',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 10,
#   'run_date': '2018-04-18 12:39'},
#  {'id': '68XjWhiMHRnJgUil5xBGJHL9q',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance AND use case',
#   'record_count': 1369,
#   'run_date': '2018-04-18 12:45'},
#  {'id': 'sBlj63nbTHuAM1Pdr4bwCbvAv',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 1300,
#   'run_date': '2018-04-18 12:46'},
#  {'id': 'mPY6Q198gMgWEix7KxnUKF1GY',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 1300,
#   'run_date': '2018-04-18 12:47'},
#  {'id': 'zCyLcShGoM8Qqy47bL2LsrgSb',
#   'id_type': 'search',
#   'input_db': 'pubmed',
#   'input_term': 'syndromic surveillance AND situational awareness',
#   'record_count': 169,
#   'run_date': '2018-04-18 13:49'},
#  {'id': 'vjzDmKduWMkuo2kGz2EqrJB1m',
#   'id_type': 'fetch',
#   'input_db': 'pubmed',
#   'record_count': 121,
#   'run_date': '2018-04-18 13:49'},
#  {'id': 'EFc4tpjsXnFT9EU45MaPmLahU',
#   'id_type': 'parse',
#   'input_db': 'pubmed',
#   'record_count': 121,
#   'run_date': '2018-04-18 13:49'},
#  {'id': '8Nbbz6E78Lp8aBqTVmMYlqgkB',
#   'id_type': 'fetch',
#   'input_db': 'springer',
#   'record_count': 50,
#   'run_date': '2018-04-20 11:17'},
#  {'id': 'NBr2c8hhGiorpIJbEmCfG9rVC',
#   'id_type': 'fetch',
#   'input_db': 'springer',
#   'record_count': 47,
#   'run_date': '2018-04-25 14:39'},
#  {'id': 'OYaerBHsKPxHEiw25tPJa4hOV',
#   'id_type': 'parse',
#   'input_db': 'springer',
#   'record_count': 47,
#   'run_date': '2018-04-25 14:52'}]

# %%
SpringerParse.main()

# %%
new_results = helper.id_run('fetch')
d = SpringerParse.parse_all(new_results)

# %%
d
# Out:
#                                              abstract  \
# 0   AbstractBackgroundRefugees may have an increas...
# 1   AbstractBackgroundWildlife rehabilitation cent...
# 2   AbstractBackgroundAs service provision and pat...
# 3   AbstractBackgroundIn the winter and spring of ...
# 4   AbstractBackgroundIn an era of ubiquitous elec...
# 5   AbstractBackgroundSyndromic surveillance has b...
# 6   AbstractDesigning effective mitigation strateg...
# 7   AbstractBackgroundTick paralysis, resultant fr...
# 8   AbstractSurveillance of epidemic outbreaks and...
# 9   AbstractBackgroundThe emergency department (ED...
# 10  AbstractBackgroundSyndromic surveillance is a ...
# 11  AbstractAchieving effective wildlife disease s...
# 12  AbstractBackgroundSyndromic surveillance syste...
# 13  AbstractBackgroundStudies into the costs of sy...
# 14  AbstractBackgroundDeath certificates provide a...
# 15  AbstractA systemic model for making sense of h...
# 16  AbstractBackgroundEarly warning and robust est...
# 17  AbstractPurposeThe purpose of this study was t...
# 18  RésuméAu Sénégal, la surveillance de la grippe...
# 19  AbstractBackgroundFor researchers and public h...
# 20  AbstractBackgroundThis systematic literature r...
# 21  AbstractThe scope of the International Health ...
# 22  AbstractBackgroundEarly knowledge of influenza...
# 23  AbstractBackgroundWe evaluated Swiss slaughter...
# 24  AbstractBackgroundAbattoir condemnation data s...
# 25  AbstractBackgroundA study of the impacts on re...
# 26  AbstractBackgroundEmergency medical service (E...
# 27  AbstractBackgroundThe objective of this study ...
# 28  AbstractBackgroundThe slaughterhouse is a cent...
# 29  AbstractBackgroundLittle is known about the po...
# 30  AbstractBackgroundAlthough an increasing numbe...
# 31  AbstractBackgroundAnimal disease monitoring an...
# 32  AbstractBackgroundA crucial goal of infectious...
# 33  AbstractBackgroundFrom January 30-February 6, ...
# 34
# 35  AbstractBackgroundWe conducted a pilot utility...
# 36  AbstractBackgroundThe importance of wildlife d...
# 37  AbstractTo better describe the epidemiology of...
# 38  ZusammenfassungZur zeitnahen Gewinnung belastb...
# 39  AbstractBackgroundOntario provincial abattoirs...
# 40  AbstractDisease surveillance makes use of info...
# 41  AbstractBackgroundThe Department of Defense Mi...
# 42  AbstractSyndromic surveillance uses new ways o...
# 43  AbstractIn 1998, the New York City Department ...
# 44  AbstractThis article presents an, algorithm fo...
# 45  AbstractSyndromic surveillance systems can det...
# 46  AbstractInterest in public health surveillance...
#
#                       associatedId  \
# 0    doi:10.1186/s12916-018-1015-9
# 1    doi:10.1186/s12917-017-1292-0
# 2    doi:10.1186/s12889-017-4372-y
# 3    doi:10.1186/s12889-017-4233-8
# 4    doi:10.1186/s12917-016-0914-2
# 5    doi:10.1186/s13104-016-2098-z
# 6    doi:10.1007/s10696-014-9204-0
# 7    doi:10.1186/s13071-016-1590-6
# 8    doi:10.1007/s10618-015-0434-x
# 9    doi:10.1186/s12873-016-0080-7
# 10   doi:10.1186/s12889-015-2680-7
# 11   doi:10.1007/s10393-015-1054-z
# 12   doi:10.1186/s12889-015-2475-x
# 13   doi:10.1186/s12913-015-0965-2
# 14   doi:10.1186/s12911-015-0174-2
# 15   doi:10.1007/s13218-015-0349-0
# 16   doi:10.1186/s12879-015-0789-z
# 17   doi:10.1007/s11250-014-0736-9
# 18   doi:10.1007/s13149-014-0390-5
# 19   doi:10.1186/s12911-014-0108-4
# 20   doi:10.1186/s12879-014-0604-2
# 21        doi:10.1057/jphp.2014.13
# 22    doi:10.1186/1471-2334-14-381
# 23     doi:10.1186/1746-6148-10-33
# 24     doi:10.1186/1746-6148-9-231
# 25     doi:10.1186/1476-069X-12-94
# 26    doi:10.1186/1471-2458-13-905
# 27    doi:10.1186/1472-6947-13-101
# 28      doi:10.1186/1746-6148-9-88
# 29     doi:10.1186/1472-6947-13-40
# 30    doi:10.1186/1471-2458-12-929
# 31     doi:10.1186/1746-6148-8-192
# 32      doi:10.1186/1472-6947-12-4
# 33      doi:10.1186/1476-069X-11-3
# 34  doi:10.1186/1753-6561-5-S6-P33
# 35     doi:10.1186/1756-0500-4-187
# 36      doi:10.1186/1746-6148-6-56
# 37     doi:10.1186/1743-422X-7-321
# 38   doi:10.1007/s00103-010-1117-9
# 39      doi:10.1186/1746-6148-6-42
# 40      doi:10.1186/1476-072X-9-16
# 41       doi:10.1186/1476-072X-9-1
# 42   doi:10.1007/s11673-009-9163-4
# 43          doi:10.1007/PL00022314
# 44          doi:10.1007/PL00022317
# 45          doi:10.1007/PL00022321
# 46          doi:10.1007/PL00022309
#
#                                                author journalISO  \
# 0   [{'first_name': ' Amanda M.', 'last_name': 'Ro...      12916
# 1   [{'first_name': ' Alba', 'last_name': 'Ana', '...      12917
# 2   [{'first_name': ' Elizabeth', 'last_name': 'Bu...      12889
# 3   [{'first_name': ' Pär', 'last_name': 'Bjelkmar...      12889
# 4   [{'first_name': ' Flavie', 'last_name': 'Vial'...      12917
# 5   [{'first_name': ' Chuchu', 'last_name': 'Ye', ...      13104
# 6   [{'first_name': ' Taesik', 'last_name': 'Lee',...      10696
# 7   [{'first_name': ' Vanina', 'last_name': 'Guern...      13071
# 8   [{'first_name': ' Liangzhe', 'last_name': 'Che...      10618
# 9   [{'first_name': ' Samantha F.', 'last_name': '...      12873
# 10  [{'first_name': ' Ruth A.', 'last_name': 'Asht...      12889
# 11  [{'first_name': ' Becki', 'last_name': 'Lawson...      10393
# 12  [{'first_name': ' Yan', 'last_name': 'Ding', '...      12889
# 13  [{'first_name': ' Yan', 'last_name': 'Ding', '...      12913
# 14  [{'first_name': ' Bevan', 'last_name': 'Koopma...      12911
# 15  [{'first_name': ' Magnus', 'last_name': 'Boman...      13218
# 16  [{'first_name': ' Lydia N', 'last_name': 'Drum...      12879
# 17  [{'first_name': ' Abu James', 'last_name': 'Su...      11250
# 18  [{'first_name': ' D.', 'last_name': 'Thiam', '...      13149
# 19  [{'first_name': ' Jian', 'last_name': 'Zou', '...      12911
# 20  [{'first_name': ' Mathilde', 'last_name': 'Piv...      12879
# 21  [{'first_name': ' Nicole', 'last_name': 'Rosen...      41271
# 22  [{'first_name': ' Solweig', 'last_name': 'Gerb...      12879
# 23  [{'first_name': ' Flavie', 'last_name': 'Vial'...      12917
# 24  [{'first_name': ' Gillian D', 'last_name': 'Al...      12917
# 25  [{'first_name': ' Brian', 'last_name': 'Thelen...      12940
# 26  [{'first_name': ' Nicole', 'last_name': 'Rosen...      12889
# 27  [{'first_name': ' Solweig', 'last_name': 'Gerb...      12911
# 28  [{'first_name': ' Céline', 'last_name': 'Dupuy...      12917
# 29  [{'first_name': ' Aaron W', 'last_name': 'Cash...      12911
# 30  [{'first_name': ' Anna', 'last_name': 'Chu', '...      12889
# 31  [{'first_name': ' Terri L', 'last_name': 'O’Su...      12917
# 32  [{'first_name': ' Wei-rong', 'last_name': 'Yan...      12911
# 33  [{'first_name': ' Andrea', 'last_name': 'Schaf...      12940
# 34  [{'first_name': ' C', 'last_name': 'King', 'co...      12919
# 35  [{'first_name': ' Blaine', 'last_name': 'Reede...      13104
# 36  [{'first_name': ' Eva', 'last_name': 'Warns-Pe...      12917
# 37  [{'first_name': ' Shui Shan', 'last_name': 'Le...      12985
# 38  [{'first_name': ' J.', 'last_name': 'Korte', '...        103
# 39  [{'first_name': ' Gillian D', 'last_name': 'Al...      12917
# 40  [{'first_name': ' Colin', 'last_name': 'Robert...      12942
# 41  [{'first_name': ' David J', 'last_name': 'Savo...      12942
# 42  [{'first_name': ' Leslie P.', 'last_name': 'Fr...      11673
# 43  [{'first_name': ' Farzad', 'last_name': 'Mosta...      11524
# 44  [{'first_name': ' Weng-Keen', 'last_name': 'Wo...      11524
# 45  [{'first_name': ' Julie A.', 'last_name': 'Pav...      11524
# 46  [{'first_name': ' Daniel M.', 'last_name': 'So...      11524
#
#                                           journalName meshterms  \
# 0                                        BMC Medicine        []
# 1                             BMC Veterinary Research        []
# 2                                   BMC Public Health        []
# 3                                   BMC Public Health        []
# 4                             BMC Veterinary Research        []
# 5                                  BMC Research Notes        []
# 6         Flexible Services and Manufacturing Journal        []
# 7                                 Parasites & Vectors        []
# 8                 Data Mining and Knowledge Discovery        []
# 9                              BMC Emergency Medicine        []
# 10                                  BMC Public Health        []
# 11                                          EcoHealth        []
# 12                                  BMC Public Health        []
# 13                       BMC Health Services Research        []
# 14        BMC Medical Informatics and Decision Making        []
# 15                        KI - Künstliche Intelligenz        []
# 16                            BMC Infectious Diseases        []
# 17              Tropical Animal Health and Production        []
# 18      Bulletin de la Société de pathologie exotique        []
# 19        BMC Medical Informatics and Decision Making        []
# 20                            BMC Infectious Diseases        []
# 21                    Journal of Public Health Policy        []
# 22                            BMC Infectious Diseases        []
# 23                            BMC Veterinary Research        []
# 24                            BMC Veterinary Research        []
# 25                               Environmental Health        []
# 26                                  BMC Public Health        []
# 27        BMC Medical Informatics and Decision Making        []
# 28                            BMC Veterinary Research        []
# 29        BMC Medical Informatics and Decision Making        []
# 30                                  BMC Public Health        []
# 31                            BMC Veterinary Research        []
# 32        BMC Medical Informatics and Decision Making        []
# 33                               Environmental Health        []
# 34                                    BMC Proceedings        []
# 35                                 BMC Research Notes        []
# 36                            BMC Veterinary Research        []
# 37                                   Virology Journal        []
# 38  Bundesgesundheitsblatt - Gesundheitsforschung ...        []
# 39                            BMC Veterinary Research        []
# 40        International Journal of Health Geographics        []
# 41        International Journal of Health Geographics        []
# 42                      Journal of Bioethical Inquiry        []
# 43                            Journal of Urban Health        []
# 44                            Journal of Urban Health        []
# 45                            Journal of Urban Health        []
# 46                            Journal of Urban Health        []
#
#                   optionalId01 optionalId02 publishdate publishdatefull  \
# 0    10.1186/s12916-018-1015-9    1741-7015        None      2018-03-19
# 1    10.1186/s12917-017-1292-0    1746-6148        None      2017-11-29
# 2    10.1186/s12889-017-4372-y    1471-2458        None      2017-05-19
# 3    10.1186/s12889-017-4233-8    1471-2458        None      2017-04-18
# 4    10.1186/s12917-016-0914-2    1746-6148        None      2016-12-20
# 5    10.1186/s13104-016-2098-z    1756-0500        None      2016-06-18
# 6    10.1007/s10696-014-9204-0    1936-6590        None      2016-06-01
# 7    10.1186/s13071-016-1590-6    1756-3305        None      2016-05-23
# 8    10.1007/s10618-015-0434-x    1573-756X        None      2016-05-01
# 9    10.1186/s12873-016-0080-7    1471-227X        None      2016-03-09
# 10   10.1186/s12889-015-2680-7    1471-2458        None      2016-01-09
# 11   10.1007/s10393-015-1054-z    1612-9210        None      2015-12-01
# 12   10.1186/s12889-015-2475-x    1471-2458        None      2015-11-14
# 13   10.1186/s12913-015-0965-2    1472-6963        None      2015-07-25
# 14   10.1186/s12911-015-0174-2    1472-6947        None      2015-07-15
# 15   10.1007/s13218-015-0349-0    1610-1987        None      2015-06-01
# 16   10.1186/s12879-015-0789-z    1471-2334        None      2015-03-01
# 17   10.1007/s11250-014-0736-9    1573-7438        None      2015-02-01
# 18   10.1007/s13149-014-0390-5    1961-9049        None      2015-02-01
# 19   10.1186/s12911-014-0108-4    1472-6947        None      2014-12-05
# 20   10.1186/s12879-014-0604-2    1471-2334        None      2014-11-18
# 21        10.1057/jphp.2014.13    1745-655X        None      2014-08-01
# 22    10.1186/1471-2334-14-381    1471-2334        None      2014-07-10
# 23     10.1186/1746-6148-10-33    1746-6148        None      2014-01-31
# 24     10.1186/1746-6148-9-231    1746-6148        None      2013-11-18
# 25     10.1186/1476-069X-12-94    1476-069X        None      2013-11-05
# 26    10.1186/1471-2458-13-905    1471-2458        None      2013-10-01
# 27    10.1186/1472-6947-13-101    1472-6947        None      2013-09-03
# 28      10.1186/1746-6148-9-88    1746-6148        None      2013-04-30
# 29     10.1186/1472-6947-13-40    1472-6947        None      2013-03-28
# 30    10.1186/1471-2458-12-929    1471-2458        None      2012-10-30
# 31     10.1186/1746-6148-8-192    1746-6148        None      2012-10-16
# 32      10.1186/1472-6947-12-4    1472-6947        None      2012-02-03
# 33      10.1186/1476-069X-11-3    1476-069X        None      2012-01-24
# 34  10.1186/1753-6561-5-S6-P33    1753-6561        None      2011-06-29
# 35     10.1186/1756-0500-4-187    1756-0500        None      2011-06-14
# 36      10.1186/1746-6148-6-56    1746-6148        None      2010-12-16
# 37     10.1186/1743-422X-7-321    1743-422X        None      2010-11-16
# 38   10.1007/s00103-010-1117-9    1437-1588        None      2010-09-01
# 39      10.1186/1746-6148-6-42    1746-6148        None      2010-08-12
# 40      10.1186/1476-072X-9-16    1476-072X        None      2010-03-12
# 41       10.1186/1476-072X-9-1    1476-072X        None      2010-01-18
# 42   10.1007/s11673-009-9163-4    1872-4353        None      2009-06-01
# 43          10.1007/PL00022314    1468-2869        None      2003-03-01
# 44          10.1007/PL00022317    1468-2869        None      2003-03-01
# 45          10.1007/PL00022321    1468-2869        None      2003-03-01
# 46          10.1007/PL00022309    1468-2869        None      2003-03-01
#
#                pubtype pullsource  \
# 0        OriginalPaper   springer
# 1        OriginalPaper   springer
# 2        OriginalPaper   springer
# 3        OriginalPaper   springer
# 4        OriginalPaper   springer
# 5        OriginalPaper   springer
# 6        OriginalPaper   springer
# 7        OriginalPaper   springer
# 8        OriginalPaper   springer
# 9        OriginalPaper   springer
# 10       OriginalPaper   springer
# 11         ReviewPaper   springer
# 12       OriginalPaper   springer
# 13       OriginalPaper   springer
# 14       OriginalPaper   springer
# 15       OriginalPaper   springer
# 16       OriginalPaper   springer
# 17  BriefCommunication   springer
# 18       OriginalPaper   springer
# 19       OriginalPaper   springer
# 20       OriginalPaper   springer
# 21       OriginalPaper   springer
# 22       OriginalPaper   springer
# 23       OriginalPaper   springer
# 24       OriginalPaper   springer
# 25       OriginalPaper   springer
# 26       OriginalPaper   springer
# 27       OriginalPaper   springer
# 28       OriginalPaper   springer
# 29       OriginalPaper   springer
# 30       OriginalPaper   springer
# 31       OriginalPaper   springer
# 32       OriginalPaper   springer
# 33       OriginalPaper   springer
# 34            Abstract   springer
# 35              Report   springer
# 36       OriginalPaper   springer
# 37              Report   springer
# 38       OriginalPaper   springer
# 39       OriginalPaper   springer
# 40         ReviewPaper   springer
# 41       OriginalPaper   springer
# 42       OriginalPaper   springer
# 43       OriginalPaper   springer
# 44       OriginalPaper   springer
# 45       OriginalPaper   springer
# 46       OriginalPaper   springer
#
#                                                 title
# 0   Clinical assessment is a neglected component o...
# 1   Syndromic surveillance for West Nile virus usi...
# 2   Correcting for day of the week and public holi...
# 3   Early outbreak detection by linking health adv...
# 4   Methodological challenges to multivariate synd...
# 5   SCM: a practical tool to implement hospital-ba...
# 6   Combining syndromic surveillance and ILI data ...
# 7   Use of big data in the surveillance of veterin...
# 8   Syndromic surveillance of Flu on Twitter using...
# 9   Human temperatures for syndromic surveillance ...
# 10  The usefulness of school-based syndromic surve...
# 11  Citizen Science and Wildlife Disease Surveillance
# 12  A cost-effectiveness analysis of three compone...
# 13  Measuring costs of data collection at village ...
# 14  Automatic classification of diseases from free...
# 15   Sensemaking in Intelligent Health Data Analytics
# 16  Assessing the use of hospital staff influenza-...
# 17  Syndromic surveillance of peste des petits rum...
# 18  Renforcement du réseau de surveillance sentine...
# 19  A Bayesian spatio–temporal approach for real–t...
# 20  Drug sales data analysis for outbreak detectio...
# 21  Non-infectious events under the International ...
# 22  Can epidemic detection systems at the hospital...
# 23  Evaluation of Swiss slaughterhouse data for in...
# 24  Comparison of covariate adjustment methods usi...
# 25  Modeling acute respiratory illness during the ...
# 26  Validity and timeliness of syndromic influenza...
# 27  Evaluation of syndromic algorithms for detecti...
# 28  Defining syndromes using cattle meat inspectio...
# 29  Relationship between the population incidence ...
# 30  The use of syndromic surveillance for decision...
# 31  Identifying an outbreak of a novel swine disea...
# 32  Establishing a web-based integrated surveillan...
# 33  Emergency department visits, ambulance calls, ...
# 34  Developing proxy indicators of healthcare asso...
# 35  Perceived usefulness of a distributed communit...
# 36  Unsupervised clustering of wildlife necropsy d...
# 37  Reconstruction of epidemic curves for pandemic...
# 38  Validierung einer syndromischen Surveillance a...
# 39  Factors associated with whole carcass condemna...
# 40  Review of software for space-time disease surv...
# 41  Enhancing spatial detection accuracy for syndr...
# 42  Syndromic Surveillance and Patients as Victims...
# 43  Use of ambulance dispatch data as an early war...
# 44         Wsare: What’s strange about recent events?
# 45  Investigation of disease outbreaks detected by...
# 46  Draft framework for evaluating syndromic surve...

# %%
dl = [d]

# %%
pd.DataFrame(dl)

# %%
term_format = 'health'
record_count = 5
api_key = 'f769b196821d177a5ca1d3252cb0bb2f'

# %%
# http://dev.springernature.com/adding-constraints
# url = 'http://api.springer.com/metadata/json?q="syndromic+surveillance"&p=10&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q=%22syndromic%20surveillance%22&p=10&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q="health"&p=70&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q=10.1007/BF01201962&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q=issn:1468-2869&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q=doi:10.1007/PL00022312&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q=keyword:Cluster analysis&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q="health"&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q="syndromic+surveillance"&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q=pub:"BioMed+Central"&api_key=f769b196821d177a5ca1d3252cb0bb2f'
url = 'http://api.springer.com/metadata/json?q=(type:Journal AND keyword:"syndromic+surveillance")&p=100&api_key=f769b196821d177a5ca1d3252cb0bb2f'

# %%
term_format = "syndromic+surveillance"
record_count = 10
url = 'http://api.springer.com/metadata/json?q=keyword:"{}"&p={}&api_key={}'.format(term_format,record_count,api_key)
url

# %%
url = 'http://api.springer.com/metadata/json?q=(type:Journal AND keyword:"{}")&p={}&api_key={}'.format(term_format,record_count,api_key)
url
# Out:
# 'http://api.springer.com/metadata/json?q=(type:Journal AND keyword:"health")&p=5&api_key=f769b196821d177a5ca1d3252cb0bb2f'

# %%
results = requests.get(url).json()

# %%
results
# Out:
# {'apiKey': 'f769b196821d177a5ca1d3252cb0bb2f',
#  'facets': [{'name': 'subject',
#    'values': [{'count': '31270', 'value': 'Medicine & Public Health'},
#     {'count': '15405', 'value': 'Public Health'},
#     {'count': '6844', 'value': 'Medicine/Public Health, general'},
#     {'count': '4876', 'value': 'Sociology, general'},
#     {'count': '4034', 'value': 'Environmental Health'},
#     {'count': '3958', 'value': 'Quality of Life Research'},
#     {'count': '3885', 'value': 'Epidemiology'},
#     {'count': '3878', 'value': 'Health Informatics'},
#     {'count': '3646', 'value': 'Psychiatry'},
#     {'count': '3240', 'value': 'Health Administration'},
#     {'count': '3019', 'value': 'Internal Medicine'},
#     {'count': '2926', 'value': 'Health Promotion and Disease Prevention'},
#     {'count': '2438', 'value': 'General Practice / Family Medicine'},
#     {'count': '2254', 'value': 'Clinical Psychology'},
#     {'count': '2224', 'value': 'Health Psychology'},
#     {'count': '2134', 'value': 'Psychology'},
#     {'count': '2032', 'value': 'Social Sciences, general'},
#     {'count': '1989', 'value': 'Biomedicine'},
#     {'count': '1969', 'value': 'Biostatistics'},
#     {'count': '1963', 'value': 'Vaccine'}]},
#   {'name': 'keyword',
#    'values': [{'count': '2810', 'value': 'Mental health'},
#     {'count': '1910', 'value': 'Health'},
#     {'count': '1694', 'value': 'Health-related quality of life'},
#     {'count': '1563', 'value': 'Public health'},
#     {'count': '907', 'value': 'Quality of life'},
#     {'count': '834', 'value': 'Health promotion'},
#     {'count': '812', 'value': 'Depression'},
#     {'count': '705', 'value': 'Primary health care'},
#     {'count': '662', 'value': 'Health disparities'},
#     {'count': '632', 'value': 'Physical activity'},
#     {'count': '627', 'value': 'Children'},
#     {'count': '592', 'value': 'Public Health'},
#     {'count': '562', 'value': 'Health care'},
#     {'count': '560', 'value': 'Adolescents'},
#     {'count': '558', 'value': 'health'},
#     {'count': '542', 'value': 'Epidemiology'},
#     {'count': '531', 'value': 'Obesity'},
#     {'count': '528', 'value': 'Health policy'},
#     {'count': '521', 'value': 'Prevention'},
#     {'count': '497', 'value': 'Health status'}]},
#   {'name': 'pub',
#    'values': [{'count': '1953', 'value': 'BMC Public Health'},
#     {'count': '1515', 'value': 'BMC Health Services Research'},
#     {'count': '1359', 'value': 'Quality of Life Research'},
#     {'count': '1010', 'value': 'Journal of General Internal Medicine'},
#     {'count': '806', 'value': 'Maternal and Child Health Journal'},
#     {'count': '718',
#      'value': 'Bundesgesundheitsblatt - Gesundheitsforschung - Gesundheitsschutz'},
#     {'count': '634', 'value': 'Journal of Immigrant and Minority Health'},
#     {'count': '603',
#      'value': 'Social Psychiatry and Psychiatric Epidemiology'},
#     {'count': '598', 'value': 'Journal of Community Health'},
#     {'count': '594', 'value': 'International Journal for Equity in Health'},
#     {'count': '515', 'value': 'Health and Quality of Life Outcomes'},
#     {'count': '501', 'value': 'Community Mental Health Journal'},
#     {'count': '414', 'value': 'Journal of Medical Systems'},
#     {'count': '406', 'value': 'International Journal of Public Health'},
#     {'count': '405', 'value': 'Journal of Urban Health'},
#     {'count': '403',
#      'value': 'Administration and Policy in Mental Health and Mental Health Services Research'},
#     {'count': '389', 'value': 'BMC Psychiatry'},
#     {'count': '376', 'value': 'BMC Pregnancy and Childbirth'},
#     {'count': '368', 'value': 'The European Journal of Health Economics'},
#     {'count': '337', 'value': 'BMC Research Notes'}]},
#   {'name': 'year',
#    'values': [{'count': '2702', 'value': '2018'},
#     {'count': '5997', 'value': '2017'},
#     {'count': '5237', 'value': '2016'},
#     {'count': '4738', 'value': '2015'},
#     {'count': '4593', 'value': '2014'},
#     {'count': '3774', 'value': '2013'},
#     {'count': '3163', 'value': '2012'},
#     {'count': '2702', 'value': '2011'},
#     {'count': '2138', 'value': '2010'},
#     {'count': '1258', 'value': '2009'},
#     {'count': '1265', 'value': '2008'},
#     {'count': '1114', 'value': '2007'},
#     {'count': '1048', 'value': '2006'},
#     {'count': '938', 'value': '2005'},
#     {'count': '768', 'value': '2004'},
#     {'count': '629', 'value': '2003'},
#     {'count': '538', 'value': '2002'},
#     {'count': '501', 'value': '2001'},
#     {'count': '425', 'value': '2000'},
#     {'count': '321', 'value': '1999'}]},
#   {'name': 'country',
#    'values': [{'count': '14876', 'value': 'United States'},
#     {'count': '5810', 'value': ''},
#     {'count': '4927', 'value': 'United Kingdom'},
#     {'count': '4095', 'value': 'Germany'},
#     {'count': '3503', 'value': 'Canada'},
#     {'count': '3109', 'value': 'Australia'},
#     {'count': '1485', 'value': 'Sweden'},
#     {'count': '1386', 'value': 'China'},
#     {'count': '1237', 'value': 'Italy'},
#     {'count': '1205', 'value': 'Switzerland'},
#     {'count': '1189', 'value': 'Spain'},
#     {'count': '1063', 'value': 'France'},
#     {'count': '954', 'value': 'India'},
#     {'count': '948', 'value': 'Norway'},
#     {'count': '868', 'value': 'Japan'},
#     {'count': '758', 'value': 'Brazil'},
#     {'count': '748', 'value': 'Belgium'},
#     {'count': '716', 'value': 'Denmark'},
#     {'count': '705', 'value': 'South Africa'},
#     {'count': '532', 'value': 'South Korea'}]},
#   {'name': 'type', 'values': [{'count': '45315', 'value': 'Journal'}]}],
#  'query': '(type:Journal AND keyword:"health")',
#  'records': [{'abstract': 'AbstractObjectives Despite increasing attention to the occupational impact of firefighting, little is known specific to the health of women firefighters. In particular, quantitative data is lacking on the impact firefighting has on maternal and child health for women who become pregnant while working as firefighters. Methods A total of 1821 women firefighters responded to requests to complete a self-report survey of questions about pregnancy. Women answered questions about their departments’ policies and practices and their own experiences of pregnancy. Those participants who reported a pregnancy while serving as a firefighter were asked detailed questions about their pregnancy and outcomes. Results Female firefighters reported that nearly a quarter of their first pregnancies while in the fire service ended in miscarriage and that increased to a third of pregnancies by the fourth. Rates of pre-term delivery also were high among this population. Conclusions Findings have important implications for policy and practice among women who become pregnant while actively serving in the fire service.',
#    'copyright': '©2018 Springer Science+Business Media, LLC, part of Springer Nature',
#    'coverDate': '',
#    'creators': [{'creator': 'Jahnke, Sara A.'},
#     {'creator': 'Poston, Walker S. C.'},
#     {'creator': 'Jitnarin, Nattinee'},
#     {'creator': 'Haddock, Christopher K.'}],
#    'doi': '10.1007/s10995-018-2468-3',
#    'eissn': '',
#    'endingPage': '931',
#    'genre': 'OriginalPaper',
#    'identifier': 'doi:10.1007/s10995-018-2468-3',
#    'issn': '1573-6628',
#    'issuetype': '',
#    'journalid': '10995',
#    'number': '6',
#    'onlineDate': '',
#    'openaccess': 'false',
#    'printDate': '',
#    'publicationDate': '2018-06-01',
#    'publicationName': 'Maternal and Child Health Journal',
#    'publisher': 'Springer',
#    'startingPage': '922',
#    'title': 'Maternal and Child Health Among Female Firefighters in the U.S.',
#    'topicalCollection': '',
#    'url': [{'format': '',
#      'platform': '',
#      'value': 'http://dx.doi.org/10.1007/s10995-018-2468-3'}],
#    'volume': '22'},
#   {'abstract': 'AbstractThis article explores the role the Black Church could play in facilitating spiritually sensitive, culturally relevant and gender-specific services to address the mental health and well-being of Black males. The help-seeking behaviors of Black men are examined as the authors offer two theories: the body, mind, spirit, environment, social, transcendent, and health, illness, men, and masculinities that may assist the Black Church in functioning as an effective support networks for healthy Black male mental health. Next, the authors discuss implications for practice, research, and education, and lastly, eight recommendations for Black Church leadership, social workers, and mental health professionals are also discussed.',
#    'copyright': '©2018 Springer Science+Business Media, LLC, part of Springer Nature',
#    'coverDate': '',
#    'creators': [{'creator': 'Robinson, Michael A.'},
#     {'creator': 'Jones-Eversley, Sharon'},
#     {'creator': 'Moore, Sharon E.'},
#     {'creator': 'Ravenell, Joseph'},
#     {'creator': 'Adedoyin, A. Christson'}],
#    'doi': '10.1007/s10943-018-0570-x',
#    'eissn': '',
#    'endingPage': '1107',
#    'genre': 'OriginalPaper',
#    'identifier': 'doi:10.1007/s10943-018-0570-x',
#    'issn': '1573-6571',
#    'issuetype': '',
#    'journalid': '10943',
#    'number': '3',
#    'onlineDate': '',
#    'openaccess': 'false',
#    'printDate': '',
#    'publicationDate': '2018-06-01',
#    'publicationName': 'Journal of Religion and Health',
#    'publisher': 'Springer',
#    'startingPage': '1095',
#    'title': 'Black Male Mental Health and the Black Church: Advancing a Collaborative Partnership and Research Agenda',
#    'topicalCollection': '',
#    'url': [{'format': '',
#      'platform': '',
#      'value': 'http://dx.doi.org/10.1007/s10943-018-0570-x'}],
#    'volume': '57'},
#   {'abstract': 'AbstractObjectives Few studies have been undertaken to determine whether and how project results are sustained. University of Notre Dame (ND) and Project Concern International conducted a Post-Project Sustainability Study (PSS) of a USAID-funded program (CHOICE), implemented in Indonesia, Banten province, between 2003 and 2007, in order to determine lasting effects and improve PSS methodologies. Methods Sustainability was measured through a comparison of data collected on mother–infant pairs in 2014 with final evaluation data from 2007; and through a comparison of 2014 data collected from the CHOICE villages and comparison villages. Results The analysis showed positive differences in multiple indicators in CHOICE villages between 2007 and 2014, including births attended by skilled personnel (Mean Difference 48.56, 95% CI 38.68 to 58.43) and treatment of diarrhea (MD 16.42, 95% CI −\u20090.94 to 33.37). However, only one statistically significant difference between intervention and comparison groups in 2014 was observed, infants with diarrhea whose mothers sought advice or treatment (MD −\u20095.48, 95% CI −\u20099.55 to 1.39), showing more mothers in intervention group sought advice or treatment. Because contextual factors were not studied in detail\xa0and baseline data was not available for the comparison villages, it is difficult to determine the reasons for the results. Given that longitudinal data was not collected, it is also difficult to determine whether results fluctuated between 2007 and 2014. Conclusions for practice This PSS contributes to the limited body of knowledge in sustainability research. Lessons learned from this study will increase potential for sustainable impact of projects, as more rigorous measurement will lead to greater overall understanding of how sustainability actually “happens”.',
#    'copyright': '©2018 Springer Science+Business Media, LLC, part of Springer Nature',
#    'coverDate': '',
#    'creators': [{'creator': 'Eder, Clara'},
#     {'creator': 'Khatiwada, Lila Kumar'},
#     {'creator': 'Schooley, Janine'}],
#    'doi': '10.1007/s10995-018-2465-6',
#    'eissn': '',
#    'endingPage': '912',
#    'genre': 'OriginalPaper',
#    'identifier': 'doi:10.1007/s10995-018-2465-6',
#    'issn': '1573-6628',
#    'issuetype': '',
#    'journalid': '10995',
#    'number': '6',
#    'onlineDate': '',
#    'openaccess': 'false',
#    'printDate': '',
#    'publicationDate': '2018-06-01',
#    'publicationName': 'Maternal and Child Health Journal',
#    'publisher': 'Springer',
#    'startingPage': '903',
#    'title': 'Sustainability of a Community-Based CHOICE Program to Improve the Health and Nutrition Status of Mothers and Infants in Indonesia',
#    'topicalCollection': '',
#    'url': [{'format': '',
#      'platform': '',
#      'value': 'http://dx.doi.org/10.1007/s10995-018-2465-6'}],
#    'volume': '22'},
#   {'abstract': 'AbstractSuicide rates among military veterans exceed those found in the general population. While the exact reasons for these high rates are unknown, contributing factors may include the military’s perceived rejection of patient identities, creating barriers to mental health care within the clinical sector and a mandate for prevention programs. Spiritual fitness has emerged over the last decade as an important concept in human performance optimization and is included among holistic approaches to developing and maintaining mentally fit fighting forces. In attempts to better understand the role that spiritual fitness and religion play in mitigating and/or reducing suicide risk among veterans, the aims of this study were twofold (1) to assess the utility of the Duke Religion Index as a psychometric instrument for use with veterans completing spiritual fitness training and (2) to offer a post-intervention process evaluation of the spiritual fitness module from one resilience program offered to military veterans of Iraq and Afghanistan in 2016. Twenty-eight attendees at the JRWI Wellness Resilient Leadership Retreat completed post-retreat surveys to assess their satisfaction with the coursework and specifically, to assess the spiritual fitness module of the resiliency retreat’s curriculum. In total, the research team reviewed 25 completed post-intervention survey responses (89.3% response rate). Descriptive statistics indicated that respondents (n\u2009=\u200925) were subjectively religious, defined as belief in a higher power practiced in ritualized ways. Over half of program participants indicated they (a) attended religious meetings at least once a week and (b) engaged in private religious activity—such as meditation—at least once a day. Results showed that most program participants reported that the spiritual fitness skills learned during the resilient leadership program were useful (88%) (Z\u2009=\u20093.000, p\u2009<\u20090.001). Additionally, most program participants reported their interest in spiritual exploration was affirmed, renewed, or raised as a result of attending the peer-led resilient leadership program (76%) (Z\u2009=\u20096.000, p\u2009=\u20090.015). Culturally informed prevention programs that emphasize spiritual fitness are indicated for use in veteran outreach and well-being programs. More detailed research is needed to assess curriculum specifics.',
#    'copyright': '©2018 Springer Science+Business Media, LLC, part of Springer Nature',
#    'coverDate': '',
#    'creators': [{'creator': 'Thomas, Kate H.'},
#     {'creator': 'McDaniel, Justin T.'},
#     {'creator': 'Albright, David L.'},
#     {'creator': 'Fletcher, Kari L.'},
#     {'creator': 'Koenig, Harold G.'}],
#    'doi': '10.1007/s10943-018-0597-z',
#    'eissn': '',
#    'endingPage': '1178',
#    'genre': 'OriginalPaper',
#    'identifier': 'doi:10.1007/s10943-018-0597-z',
#    'issn': '1573-6571',
#    'issuetype': '',
#    'journalid': '10943',
#    'number': '3',
#    'onlineDate': '',
#    'openaccess': 'false',
#    'printDate': '',
#    'publicationDate': '2018-06-01',
#    'publicationName': 'Journal of Religion and Health',
#    'publisher': 'Springer',
#    'startingPage': '1168',
#    'title': 'Spiritual Fitness for Military Veterans: A Curriculum Review and Impact Evaluation Using the Duke Religion Index (DUREL)',
#    'topicalCollection': '',
#    'url': [{'format': '',
#      'platform': '',
#      'value': 'http://dx.doi.org/10.1007/s10943-018-0597-z'}],
#    'volume': '57'},
#   {'abstract': 'AbstractLesbian, gay, bisexual, transgender, and other sexual and gender minority (LGBTQ) adolescents experience higher rates of negative sexual health outcomes relative to their heterosexual and cisgender peers. Healthy parent-adolescent relationships and effective parenting are robust predictors of sexual health in heterosexual adolescents, but very little is known about barriers to and facilitators of effective parenting from the perspective of parents of LGBTQ adolescents. This study conducted online focus groups with 44 parents of LGBTQ adolescents in order to describe the factors influencing effective sexual health communication and parental monitoring in this population. Parents described generally positive relationships with teens, but many noted they went through a transition process in which they struggled with their child’s identity and were less supportive of their LGBTQ teen. Lack of understanding about LGBTQ-specific sexuality was a commonly endorsed barrier to effective communication, and this was most commonly endorsed by parents of cisgender girls. Parents of cisgender boys and transgender/gender-nonconforming teens described fears about long-term sexual health (i.e., sexual predators, consent) as a barrier to parental monitoring. Parents of LGBTQ adolescents need information and skills to optimize their teen’s sexual health. Parent-based programs for LGBTQ adolescents are long overdue for addressing these issues.',
#    'copyright': '©2018 Springer Science+Business Media, LLC, part of Springer Nature',
#    'coverDate': '',
#    'creators': [{'creator': 'Newcomb, Michael E.'},
#     {'creator': 'Feinstein, Brian A.'},
#     {'creator': 'Matson, Margaret'},
#     {'creator': 'Macapagal, Kathryn'},
#     {'creator': 'Mustanski, Brian'}],
#    'doi': '10.1007/s13178-018-0326-0',
#    'eissn': '',
#    'endingPage': '122',
#    'genre': 'OriginalPaper',
#    'identifier': 'doi:10.1007/s13178-018-0326-0',
#    'issn': '1553-6610',
#    'issuetype': '',
#    'journalid': '13178',
#    'number': '2',
#    'onlineDate': '',
#    'openaccess': 'false',
#    'printDate': '',
#    'publicationDate': '2018-06-01',
#    'publicationName': 'Sexuality Research and Social Policy',
#    'publisher': 'Springer',
#    'startingPage': '111',
#    'title': '“I Have No Idea What’s Going On Out There:” Parents’ Perspectives on Promoting Sexual Health in Lesbian, Gay, Bisexual, and Transgender Adolescents',
#    'topicalCollection': '',
#    'url': [{'format': '',
#      'platform': '',
#      'value': 'http://dx.doi.org/10.1007/s13178-018-0326-0'}],
#    'volume': '15'}],
#  'result': [{'pageLength': '5',
#    'recordsDisplayed': '5',
#    'start': '1',
#    'total': '45315'}]}

# %%
url
# Out:
# 'http://api.springer.com/metadata/json?q=keyword:"syndromic+surveillance"&api_key=f769b196821d177a5ca1d3252cb0bb2f'

# %%
[a.keys() for a in results['facets']]
[a['name']=='type' for a in results['facets']]

# %%
results['records'][4]

# %%
results

# %%
results['facets']['name'=='keyword']

# %%
author_list = a[0]['creators']
auth_list = [b['creator'] for b in author_list]
auth_list
[c.split(',') for c in auth_list]

# %%
a[1]

# %%
a = results['records']
[b['genre'] for b in a]
abstract = a[0]['abstract']

# %%
def camel(s):
    return (s != s.lower() and s!=s.upper())

# %%
word_list = []
for word in abstract_full.split():
    if (word != word.lower() and word != word.upper()):
        word_list.append(word)

# %%
# regexp = re.compile(".(*)$")
# abstract_full.partition('.')
# regexp.search(abstract_full).group(1)

# %%
word_list

# %%
abstract_full = abstract.replace('Abstract',"")
abstract

# %%
p = re.compile(r'Abstract(.*?)\.|\.([A-Z])(.*?)\.')
word_list = []
for m in p.finditer(abstract):
    word_list.append(m.group())
#     print(m.group())

words_dirty = [w.split()[0] for w in word_list]

# %%
[w.split()[0] for w in word_list]

# %%
clean_word_list = []
for word in words_dirty:
    if '.' in word:
#         print(word)
        clean_words = word.replace('.',word)
        clean_word_list.append(clean_words)

# %%
clean_word_list

# %%
abstract_full = abstract.replace('Abstract',"")
# abstract_background
abstract_list = re.split('Background|Intro|Methods|Results|Discussion|Conclusion',abstract_full)
# re.split('Introduction',abstract_full)
# abstract_list
abstract_full.split('Background')
# abstract_full

# %%
abstract.split("Background")

# %%
camel(abstract)

# %%
'MethodsWe' in abstract

# %%
a[1]

# %%
results['result']

# %%
results.keys()

# %%
springer_fetch_inst = SpringerFetch.springer_fetch(input_term,api_key)

# %%
url = springer_fetch_inst.ping_api()

# %%
results,record_count = springer_fetch_inst.pull_results(url)

prop_dict = springer_fetch_inst.search_properties(record_count)

unique_id = prop_dict['id']

# %%
prop_dict

# %%
new_results = helper.id_run('fetch')

# %%
a = results['records']

# %%
a

# %%
a['doi']

# %%
# url = 'http://api.springer.com/openaccess/json?q=(type:Journal AND "{}")&p={}&api_key={}'.format('health',10,api_key)
url = 'http://api.springer.com/openaccess/json?q="{}"&p={}&api_key={}'.format('syndromic+surveillance',5,api_key)

# %%
url

# %%
# http://dev.springernature.com/adding-constraints
# url = 'http://api.springer.com/metadata/json?q="syndromic+surveillance"&p=10&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q=%22syndromic%20surveillance%22&p=10&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q="health"&p=70&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q=10.1007/BF01201962&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q=issn:1468-2869&api_key=f769b196821d177a5ca1d3252cb0bb2f'
url = 'http://api.springer.com/metadata/json?q=doi:10.1007/PL00022312&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q=keyword:Cluster analysis&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q=keyword:"syndromic+surveillance"&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q="syndromic+surveillance"&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# url = 'http://api.springer.com/metadata/json?q=pub:"BioMed+Central"&api_key=f769b196821d177a5ca1d3252cb0bb2f'
# 'BioMed Central'
# url = 'http://api.springer.com/meta/v1/json?q=openaccess:true&api_key=f769b196821d177a5ca1d3252cb0bb2f'

# %%
results = requests.get(url).json()

# %%
results

# %%
results.keys()

# %%
results['query']

# %%
results['records'][0].keys()

# %%
results['records']

# %%
results['result']

# %%
d_springer = requests.get(base_url_springer + springer_keyword,params=url_params_springer).json()
	#for Gitbash
	print "--------Result of Springer Metadata API-----------"
	#print pretty(d_springer)[:2000]
	# cache the data from Scopus and collected
	fr_springer = open("springer_abstract.txt","w")
	fr_springer.write(json.dumps(d_springer))
	fr_springer.close()
